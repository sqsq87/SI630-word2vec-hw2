# %%
import csv
import math
import pickle
import random
import sys
from collections import Counter
import numpy as np

# Hhelpful for computing cosine similarity
from scipy.spatial.distance import cosine

# This will make things go fast when we finally use it
from numba import jit

# Handy command-line argument parsing
import argparse

# Progress bar tracker
from tqdm import tqdm

# Sort of smart tokenization
from nltk.tokenize import RegexpTokenizer

# We'll use this to save our models
from gensim.models import KeyedVectors

random.seed(1234)
np.random.seed(1234)

# %%
class word2vec:
    def __init__(self, hidden_layer_size=50):

        self.hidden_layer_size = hidden_layer_size
        self.tokenizer = RegexpTokenizer(r'\w+')
        
        # These state variables become populated as the main() function calls
        #
        # 1. load_data()
        # 2. generate_negative_sampling_table()
        # 3. init_weights()
        #
        # See those functions for how the various values get filled in

        self.word_to_index = {} # word to unique-id
        self.index_to_word = [] # unique-id to word

        # How many times each word occurs in our data after filtering
        self.word_counts = Counter()

        # A utility data structure that lets us quickly sample "negative"
        # instances in a context. This table contains unique-ids
        self.negative_sampling_table = []
        
        # The dataset we'll use for training, as a sequence of unqiue word
        # ids. This is the sequence across all documents after tokens have been
        # randomly subsampled by the word2vec preprocessing step
        self.full_token_sequence_as_ids = []

        # These will contain the two weight matrices. W is the embeddings for
        # the center/target word and C are the embeddings for the context
        # words. You might see these called (W, V) or (W1, W2) in various
        # documentation too. These get initalized later in init_weights() once
        # we know the vocabulary size
        self.W = None
        self.C = None
        
    def tokenize(self, text):
        '''
        Tokenize the document and returns a list of the tokens
        '''
        return self.tokenizer.tokenize(text)

        
    def load_data(self, file_name, min_token_freq):
        '''
        Reads the data from the specified file as long long sequence of text
        (ignoring line breaks) and populates the data structures of this
        word2vec object.
        '''

        # Step 1: Read in the file and create a long sequence of tokens
        with open(file_name,"r") as f:   
            original_sequence= f.read()  
        tokens=self.tokenize(original_sequence)
        # Step 2: Count how many tokens we have of each type
        print('Counting token frequencies')
        original_frequency=Counter(tokens)
        

        # Step 3: Replace all tokens below the specified frequency with an <UNK>
        # token
        print("Performing minimum thresholding")
        for i in range(len(tokens)):
            if original_frequency[tokens[i]]<min_token_freq:
                tokens[i]='<UNK>'

        # Step 4: update self.word_counts to be the number of times each word
        # occurs (including <UNK>)
        self.word_counts=Counter(tokens)

        # Step 5: Create the mappings from word to unique integer ID and the
        # reverse mapping.
        #
        # HINT: the id-to-word mapping is easily represented as a list data
        # structure
    
        all_words=list(self.word_counts.keys())
        for i in range(len(all_words)):
            self.word_to_index[all_words[i]]=i
        self.index_to_word=all_words
        
        # Step 6: Compute the probability of keeping any particular token of a
        # word in the training sequence, which we'll use to subsample. This
        # avoids having the training data be filled with many overly common words
        probability={}
        for i in all_words:
            temp_p=self.word_counts[i]/len(tokens)
            #print(temp_p)
            probability[i]=(np.sqrt(temp_p/0.001)+1)*0.001/temp_p
        #print(probability)
        # Step 7: process the list of tokens (after min-freq filtering) to fill
        # a new list self.full_token_sequence_as_ids where (1) we
        # probabilistically choose whether to keep each token based on the
        # subsampling probabilities and (2) all tokens are convered to their
        # unique ids for faster training.
        for i in range(len(tokens)):
            self.full_token_sequence_as_ids.append(self.word_to_index[tokens[i]])
        print(len(tokens))
        # Transform the original input into a sequence of IDs while also
        # performing token-based subsampling based on the probabilities in
        # word_to_sample_prob. This effectively makes the context window larger
        # for some words by removing words that are common from a particular
        # context before the training occurs.
        for i in all_words:
            if probability[i]<1:
                reserve=np.random.binomial(1,probability[i],1)[0]
                if reserve==0:
                    self.full_token_sequence_as_ids=list(filter(lambda x:x!=self.word_to_index[i],self.full_token_sequence_as_ids))

        # self.negative_sampling_table = generate_negative_sampling_table()
        print('Loaded all data from %s; saw %d tokens (%d unique)' \
              % (file_name, len(self.full_token_sequence_as_ids),
                 len(self.word_to_index)))
                
    
    def generate_negative_sampling_table(self, exp_power=0.75, table_size=1e6):
        '''
        Generates a big list data structure that we can quickly randomly index into
        in order to select a negative training example (i.e., a word that was
        *not* present in the context). 
        '''       
        
        # Step 1: Figure out how many instances of each word need to go into the
        # negative sampling table. 
        #
        # HINT: np.power and np.fill might be useful here        
        print("Generating sampling table")
        len_word=[]
        sum_len_word=sum(np.power(list(self.word_counts.values()),exp_power))
        for i in self.index_to_word:
            len_word.append(np.power(self.word_counts[i],exp_power)/sum_len_word)
        len_word=(np.asarray(len_word)*table_size).astype(int)




        print(len(len_word))
        # Step 2: Create the table to the correct size. You'll want this to be a
        # numpy array of type int
        self.negative_sampling_table=np.ones(int(table_size)).astype(int)


        # Step 3: Fill the table so that each word has a number of IDs
        # proportionate to its probability of being sampled.
        #
        # Example: if we have 3 words "a" "b" and "c" with probabilites 0.5,
        # 0.33, 0.16 and a table size of 6 then our table would look like this
        # (before converting the words to IDs):
        #
        # [ "a", "a", "a", "b", "b", "c" ]
        #
        index_temp=0
        sum_temp=0
        #print(len_word)
        for i in range(len(len_word)):
            np.ndarray.fill(self.negative_sampling_table[sum_temp:(sum_temp+len_word[i])],index_temp)
            sum_temp=sum_temp+len_word[i]
            index_temp=index_temp+1


    def generate_negative_samples(self, cur_context_word_id, num_samples):
        '''
        Randomly samples the specified number of negative samples from the lookup
        table and returns this list of IDs as a numpy array. As a performance
        improvement, avoid sampling a negative example that has the same ID as
        the current positive context word.
        '''

        # Step 1: Create a list and sample from the negative_sampling_table to
        # grow the list to num_samples, avoiding adding a negative example that
        # has the same ID as teh current context_word
        results = []
        temp_num_sample=0
        while temp_num_sample<num_samples:
            temp=np.random.choice(self.negative_sampling_table,1)[0]
            if temp!=cur_context_word_id:
                results.append(temp)
                temp_num_sample=temp_num_sample+1
            else:
                pass

        # Step 2: Convert the list of samples to numpy array and return it            
        return np.array(results)
    def save(self, filename):
        '''
        Saves the model to the specified filename as a gensim KeyedVectors in the
        text format so you can load it separately.
        '''

        # Creates an empty KeyedVectors with our embedding size
        kv = KeyedVectors(vector_size=self.hidden_layer_size)        
        vectors = []
        words = []
        # Get the list of words/vectors in a consistent order
        for index, word in enumerate(self.index_to_word): 
            vectors.append(self.W[index].copy())
            words.append(word)
            
        # Fills the KV object with our data in the right order
        kv.add(words, vectors) 
        kv.save_word2vec_format(filename, binary=False)
    def init_weights(self, init_range=0.1):
        '''
        Initializes the weight matrices W (input->hidden) and C (hidden->output)
        by sampling uniformly within a small range around zero.
        '''

        # Step 1: Initialize two numpy arrays (matrices) for W and C by filling
        # their values with a random sample within the speified range.
        #
        # Hint: numpy.random has lots of ways to create matrices for this task
        self.W=np.random.uniform(-init_range,init_range,size=(len(self.word_to_index),self.hidden_layer_size))
        self.C=np.random.uniform(-init_range,init_range,size=(len(self.word_to_index),self.hidden_layer_size))
        
    def train(self, num_epochs=2, window_size=2, num_negative_samples=2,
              learning_rate=0.05, nll_update_iter=10000, max_steps=-1):
        '''
        Trains the word2vec model on the data loaded from load_data for the
        specified number of epochs.
        '''

        # Rather than compute the full negative log-likelihood (NLL), we'll keep
        # a running tally of the nll values for each step and periodically report them
        nll_results = []
        
        # This value keeps track of which step we're on. Since we don't update
        # when the center token is "<UNK>" we may skip over some ids in the
        # inner loop, so we need a separate step count to keep track of how many
        # updates we've done.
        step = 0
        
        # Iterate for the specified number of epochs
        for epoch in range(1, num_epochs+1):
            print("Beginning epoch %d of %d" % (epoch, num_epochs))           
            
            # Step 1: Iterate over each ID in full_token_sequence_as_ids as a center
            # token (skipping those that are <UNK>) and predicting the context
            # word and negative samples
            #
            # Hint: this is a great loop to wrap with a tqdm() call so you can
            # see how long each epoch will take with a progress bar
            overall_length=len(self.full_token_sequence_as_ids)
            for i in range(overall_length):
                center_word=self.full_token_sequence_as_ids[i]
                if self.index_to_word[center_word]=='<UNK>':
                    continue
                window_begin=(i-window_size)
                window_end=(i+1+window_size)
                if window_begin>=0 and window_end<=overall_length:
                    context_word=self.full_token_sequence_as_ids[window_begin:window_begin+2]+self.full_token_sequence_as_ids[window_end-2:window_end]
                elif window_begin<0:
                    context_word=self.full_token_sequence_as_ids[0:window_begin+2]+self.full_token_sequence_as_ids[window_end-2:window_end]
                elif window_end>overall_length:
                    context_word=self.full_token_sequence_as_ids[window_begin:window_begin+2]+self.full_token_sequence_as_ids[window_end-2:overall_length]
                # Periodically print the NLL so we can see how the model is converging
                if nll_update_iter > 0 and step % nll_update_iter == 0 and step > 0 and len(nll_results) > 0:
                    print("Negative log-likelihood (step: %d): %f " % (step, sum(nll_results)))
                    nll_results = []
                                    
                # Step 2: For each word in the window range (before and after)
                # perform an update where we (1) use the current parameters of
                # the model to predict it using the skip-gram task and (2)
                # sample negative instances and predict those. We'll use the
                # values of those predictions (i.e., the output of the sigmoid)
                # to update the W and C matrices using backpropagation.
                #
                # NOTE: this inner loop should call predict_and_backprop() which is
                # defined outside of the class. See note there for why.
                for each_context in context_word:

                    # Step 3: Pick the context word ID
                    

                    # Step 4: Sample negative instances 
                    negative_sample_instances=self.generate_negative_samples(each_context,num_negative_samples)

                    # Step 5: call predict_and_backprop. Don't forget to add the
                    # nll return value to nll_results to keep track of how the
                    # model is learning
                    nll=predict_and_backprop(self.W,self.C,learning_rate,center_word,each_context,negative_sample_instances)
                    nll_results.append(nll)
                    #print(nll_results)

                    
                step += 1
                #print(step)
                if max_steps > 0 and step >= max_steps:
                    break

            if max_steps > 0 and step >= max_steps:
                print('Maximum number of steps reached: %d' % max_steps)
                break
    def get_neighbors(self, target_word):
        """ 
        Finds the top 10 most similar words to a target word
        """
        outputs = []
        for index, word in tqdm(enumerate(self.index_to_word), total=len(self.index_to_word)):
            similarity = self.compute_cosine_similarity(target_word, word)
            result = {"word": word, "score": similarity}
            outputs.append(result)
    
        # Sort by highest scores
        neighbors = sorted(outputs, key=lambda o: o['score'], reverse=True)
        return neighbors[1:11]

    def compute_cosine_similarity(self, word_one, word_two):
        '''
        Computes the cosine similarity between the two words
        '''
        try:
            word_one_index = self.word_to_index[word_one]
            word_two_index = self.word_to_index[word_two]
        except KeyError:
            return 0
    
        embedding_one = self.W[word_one_index]
        embedding_two = self.W[word_two_index]
        similarity = 1 - abs(float(cosine(embedding_one, embedding_two)))
        return similarity

# %%
#@jit(nopython=True)
def predict_and_backprop(W, C, learning_rate, center_id, context_id,
                         negative_sample_ids):
    '''
    Using the center token (specified by center_id), makes a forward pass through
    the network to predict the context token (context_id) and negative samples,
    then backprops the error of those predictions to update the network and
    returns the negative log likelihood (Equation 1 in your homework) from the
    current preditions. W and C are the weight matrices of the network and IDs
    refer to particular rows of the matrices (i.e., the word embeddings of the
    target word and the context words!)

    '''

    #
    # GENERAL NOTE: There are many ways to implement this function, depending on
    # how fancy you want to get with numpy. The instructions/steps here are
    # intended as guides for the main tasks on what you have to do and may be
    # implemented as one line or more lines, depending on which methods you use
    # and how you want to write it. The important thing is that it works, not
    # how fast it is, so feel free to write it in a way that is understandable
    # to you. Often when you get to that point, you'll see ways to improve (but
    # first save a copy of your working code!).
    #

    
    # Step 1: Look up the two vectors in W and C. Note that the row for the
    # center_id is effectively the hidden layer activation, h.
    center_vec=W[center_id]
    context_vec=C[context_id]
    # Step 2: Look up the vectors for the negative sample IDs.
    #
    
    
    negative_sample_vecs=C[negative_sample_ids]
    # NOTE: numpy supports multiple indexing (getting multiple rows at once) if
    # you want to use it

    # Step 3: Compute the predictions for the context word and the negative
    # examples. We want the predictions of the context word to be near 1 and
    # those for the negative examples to be near 0.
    context_word_prediction=np.dot(center_vec,context_vec)
    negative_word_prediction=np.matmul(negative_sample_vecs,np.transpose([center_vec]))
    # Step 4: Compute the negative log likelihood
    nll=-np.log(sigmoid(context_word_prediction))-np.sum(np.log(sigmoid(-negative_word_prediction)))
    # Step 5: Update the negative sample vectors to push their dot product with the
    # center word's vecter closer to zero.
    context_vec_new=context_vec-learning_rate*(sigmoid(context_word_prediction)-1)*center_vec
    negative_sample_vecs_new=negative_sample_vecs-np.matmul(learning_rate*(sigmoid(negative_word_prediction)),[center_vec])
    # Step 6: Now backprop all the way back to the center word's vector. Be sure to
    # update it based on the *old* values of the context vectors, not the
    # new values of the context vectors that you just updated!    
    center_vec_new=center_vec-learning_rate*(sigmoid(context_word_prediction)-1)*context_vec
    for i in range(len(negative_word_prediction)):
        center_vec_new=center_vec_new-learning_rate*(sigmoid(negative_word_prediction[i]))*negative_sample_vecs[i]
    #nll = 0
    W[center_id]=center_vec_new
    C[context_id]=context_vec_new
    C[negative_sample_ids]=negative_sample_vecs_new
    return nll
#@jit(nopython=True)
def sigmoid(x):
    '''
    Returns the sigmoid of the provided value
    '''
    return 1.0 / (1 + np.exp(-x))

# %%
parser = argparse.ArgumentParser()

parser.add_argument('--corpus_file',
                    type=str,
                    default='wiki-bios.med.txt',
                    help="The file name for the text file to use in training")

parser.add_argument(
    '--window_size',
    type=int,
    default=2,
    help=
    "The number of tokens before or after the center token to include as context when training"
)
parser.add_argument(
    '--learning_rate',
    type=float,
    default=0.05,
    help="The learning rate to use when updating embeddings during SGD")
parser.add_argument(
    '--embedding_size',
    type=int,
    default=50,
    help="The embedding dimension side (i.e., hidden layer size)")

parser.add_argument(
    '--min_token_frequency',
    type=int,
    default=5,
    help=
    "The minimum number of times a token must occur to be considered in the vocabulary"
)

parser.add_argument(
    '--num_epochs',
    type=int,
    default=2,
    help=
    "The number of epochs of training to complete, where an epoch is a full pass through the entire data."
)

parser.add_argument(
    '--max_steps',
    type=int,
    default=-1,
    help=
    "The maximum number of steps to take. Positive values will cause the training to end early if the maximum number is reached before all epochs have finished."
)

parser.add_argument(
    '--nll_update_iter',
    type=int,
    default=10000,
    help=
    "How many steps to take between printing the negative log-likelihood when testing for convergence. Negative values cause the NLL to not be printed"
)

parser.add_argument('--do_quick_nn_test',
                    type=bool,
                    default=True,
                    help="Run a quick nearest-neighbor test")

parser.add_argument(
    '--output_file',
    type=str,
    default='trained_vector.txt',
    help="Where to save the word vectors as a gensim.KeyedVectors")

args = parser.parse_args(args=[])
if not args.corpus_file:
        print('No file specified for training! See help message:\n')
        parser.print_help(sys.stderr)
        exit(1)

if not args.output_file:
        print('REMINDER: this run is not saving any output. If you meant to, restart and add --output_file')
        
corpus_file_name = args.corpus_file

# %%
instance=word2vec()

# %%
instance.load_data(corpus_file_name, args.min_token_frequency)
# Out:
# Counting token frequencies
# Performing minimum thresholding
# 23015360
# Loaded all data from wiki-bios.med.txt; saw 18594088 tokens (108206 unique)

# %%
instance.init_weights()

# %%
instance.generate_negative_sampling_table()
# Out:
# Generating sampling table
# 108206

# %%
instance.train(nll_update_iter=args.nll_update_iter, max_steps=args.max_steps,
                num_epochs=args.num_epochs)
# Out:
# Beginning epoch 1 of 2
# Negative log-likelihood (step: 10000): 81766.082953
# Negative log-likelihood (step: 20000): 79209.344167
# Negative log-likelihood (step: 30000): 77756.214706
# Negative log-likelihood (step: 40000): 76804.980325
# Negative log-likelihood (step: 50000): 77036.815022
# Negative log-likelihood (step: 60000): 75697.123899
# Negative log-likelihood (step: 70000): 74783.416381
# Negative log-likelihood (step: 80000): 75765.061278
# Negative log-likelihood (step: 90000): 73871.414029
# Negative log-likelihood (step: 100000): 73411.041552
# Negative log-likelihood (step: 110000): 73583.060948
# Negative log-likelihood (step: 120000): 73540.303606
# Negative log-likelihood (step: 130000): 71515.316059
# Negative log-likelihood (step: 140000): 70443.127895
# Negative log-likelihood (step: 150000): 72309.516773
# Negative log-likelihood (step: 160000): 70471.715172
# Negative log-likelihood (step: 170000): 72026.598981
# Negative log-likelihood (step: 180000): 67902.238340
# Negative log-likelihood (step: 190000): 70871.217776
# Negative log-likelihood (step: 200000): 68983.074564
# Negative log-likelihood (step: 210000): 68564.101612
# Negative log-likelihood (step: 220000): 68613.497773
# Negative log-likelihood (step: 230000): 68802.210508
# Negative log-likelihood (step: 240000): 68657.086478
# Negative log-likelihood (step: 250000): 65624.995525
# Negative log-likelihood (step: 260000): 62826.700612
# Negative log-likelihood (step: 270000): 68490.281618
# Negative log-likelihood (step: 280000): 68139.210374
# Negative log-likelihood (step: 290000): 68603.877583
# Negative log-likelihood (step: 300000): 67811.515556
# Negative log-likelihood (step: 310000): 68990.441587
# Negative log-likelihood (step: 320000): 67482.459411
# Negative log-likelihood (step: 330000): 67145.562639
# Negative log-likelihood (step: 340000): 65085.578413
# Negative log-likelihood (step: 350000): 65911.255495
# Negative log-likelihood (step: 360000): 65142.644359
# Negative log-likelihood (step: 370000): 67720.691039
# Negative log-likelihood (step: 380000): 65873.819529
# Negative log-likelihood (step: 390000): 66863.769608
# Negative log-likelihood (step: 400000): 66993.205813
# Negative log-likelihood (step: 410000): 66571.774136
# Negative log-likelihood (step: 420000): 65990.525372
# Negative log-likelihood (step: 430000): 63295.449543
# Negative log-likelihood (step: 440000): 64768.079170
# Negative log-likelihood (step: 450000): 63616.769173
# Negative log-likelihood (step: 460000): 65784.724963
# Negative log-likelihood (step: 470000): 66372.285808
# Negative log-likelihood (step: 480000): 60299.009189
# Negative log-likelihood (step: 490000): 66226.146240
# Negative log-likelihood (step: 500000): 64946.499553
# Negative log-likelihood (step: 510000): 65059.955193
# Negative log-likelihood (step: 520000): 64174.487048
# Negative log-likelihood (step: 530000): 63823.867938
# Negative log-likelihood (step: 540000): 65075.141710
# Negative log-likelihood (step: 550000): 63751.134359
# Negative log-likelihood (step: 560000): 64052.147719
# Negative log-likelihood (step: 570000): 60838.751342
# Negative log-likelihood (step: 580000): 64093.850061
# Negative log-likelihood (step: 590000): 64345.718803
# Negative log-likelihood (step: 600000): 64490.321501
# Negative log-likelihood (step: 610000): 63586.296492
# Negative log-likelihood (step: 620000): 63826.669676
# Negative log-likelihood (step: 630000): 63684.422956
# Negative log-likelihood (step: 640000): 60418.375303
# Negative log-likelihood (step: 650000): 63750.797149
# Negative log-likelihood (step: 660000): 62408.105715
# Negative log-likelihood (step: 670000): 64784.122913
# Negative log-likelihood (step: 680000): 63601.589598
# Negative log-likelihood (step: 690000): 63945.990624
# Negative log-likelihood (step: 700000): 61032.524851
# Negative log-likelihood (step: 710000): 62424.177860
# Negative log-likelihood (step: 720000): 62192.053458
# Negative log-likelihood (step: 730000): 62114.603337
# Negative log-likelihood (step: 740000): 62965.076639
# Negative log-likelihood (step: 750000): 60863.638253
# Negative log-likelihood (step: 760000): 61113.461682
# Negative log-likelihood (step: 770000): 62640.482208
# Negative log-likelihood (step: 780000): 62265.396606
# Negative log-likelihood (step: 790000): 62035.723102
# Negative log-likelihood (step: 800000): 62418.938390
# Negative log-likelihood (step: 810000): 61290.892282
# Negative log-likelihood (step: 820000): 59208.142491
# Negative log-likelihood (step: 830000): 62900.251664
# Negative log-likelihood (step: 840000): 59712.986646
# Negative log-likelihood (step: 850000): 62302.322718
# Negative log-likelihood (step: 860000): 56469.596676
# Negative log-likelihood (step: 870000): 61570.629839
# Negative log-likelihood (step: 880000): 60661.851017
# Negative log-likelihood (step: 890000): 60892.091617
# Negative log-likelihood (step: 900000): 59955.696584
# Negative log-likelihood (step: 910000): 61212.414444
# Negative log-likelihood (step: 920000): 60886.357036
# Negative log-likelihood (step: 930000): 60881.208750
# Negative log-likelihood (step: 940000): 61495.212390
# Negative log-likelihood (step: 950000): 60662.921538
# Negative log-likelihood (step: 960000): 56122.239135
# Negative log-likelihood (step: 970000): 59360.579264
# Negative log-likelihood (step: 980000): 61139.593613
# Negative log-likelihood (step: 990000): 61081.650818
# Negative log-likelihood (step: 1000000): 59757.347211
# Negative log-likelihood (step: 1010000): 61955.125067
# Negative log-likelihood (step: 1020000): 61130.295718
# Negative log-likelihood (step: 1030000): 60571.227943
# Negative log-likelihood (step: 1040000): 60784.472728
# Negative log-likelihood (step: 1050000): 59796.592146
# Negative log-likelihood (step: 1060000): 60905.435736
# Negative log-likelihood (step: 1070000): 59942.282458
# Negative log-likelihood (step: 1080000): 59822.186504
# Negative log-likelihood (step: 1090000): 58361.222729
# Negative log-likelihood (step: 1100000): 59654.489216
# Negative log-likelihood (step: 1110000): 60375.855013
# Negative log-likelihood (step: 1120000): 56234.872642
# Negative log-likelihood (step: 1130000): 57513.404981
# Negative log-likelihood (step: 1140000): 61177.181733
# Negative log-likelihood (step: 1150000): 61443.685919
# Negative log-likelihood (step: 1160000): 61261.428535
# Negative log-likelihood (step: 1170000): 60694.689825
# Negative log-likelihood (step: 1180000): 60801.234835
# Negative log-likelihood (step: 1190000): 60353.199426
# Negative log-likelihood (step: 1200000): 58679.068285
# Negative log-likelihood (step: 1210000): 57651.313005
# Negative log-likelihood (step: 1220000): 60040.003115
# Negative log-likelihood (step: 1230000): 59634.950858
# Negative log-likelihood (step: 1240000): 62131.203110
# Negative log-likelihood (step: 1250000): 59465.483747
# Negative log-likelihood (step: 1260000): 60426.379683
# Negative log-likelihood (step: 1270000): 60916.173741
# Negative log-likelihood (step: 1280000): 57877.142735
# Negative log-likelihood (step: 1290000): 58630.451103
# Negative log-likelihood (step: 1300000): 58422.073240
# Negative log-likelihood (step: 1310000): 58767.837922
# Negative log-likelihood (step: 1320000): 60079.367439
# Negative log-likelihood (step: 1330000): 59309.689579
# Negative log-likelihood (step: 1340000): 61990.779407
# Negative log-likelihood (step: 1350000): 60554.943714
# Negative log-likelihood (step: 1360000): 58898.703045
# Negative log-likelihood (step: 1370000): 56199.295162
# Negative log-likelihood (step: 1380000): 60984.171642
# Negative log-likelihood (step: 1390000): 59002.790215
# Negative log-likelihood (step: 1400000): 56864.258486
# Negative log-likelihood (step: 1410000): 55309.190208
# Negative log-likelihood (step: 1420000): 60510.155495
# Negative log-likelihood (step: 1430000): 59059.074687
# Negative log-likelihood (step: 1440000): 59841.536117
# Negative log-likelihood (step: 1450000): 55275.432578
# Negative log-likelihood (step: 1460000): 59571.655056
# Negative log-likelihood (step: 1470000): 59329.520992
# Negative log-likelihood (step: 1480000): 59131.731220
# Negative log-likelihood (step: 1490000): 58115.099843
# Negative log-likelihood (step: 1500000): 59129.004416
# Negative log-likelihood (step: 1510000): 55519.673607
# Negative log-likelihood (step: 1520000): 57439.875453
# Negative log-likelihood (step: 1530000): 60362.749707
# Negative log-likelihood (step: 1540000): 58795.298513
# Negative log-likelihood (step: 1550000): 59590.284886
# Negative log-likelihood (step: 1560000): 59407.357223
# Negative log-likelihood (step: 1570000): 58001.562875
# Negative log-likelihood (step: 1580000): 56909.057372
# Negative log-likelihood (step: 1590000): 55282.422407
# Negative log-likelihood (step: 1600000): 59049.059433
# Negative log-likelihood (step: 1610000): 59880.067877
# Negative log-likelihood (step: 1620000): 54830.994580
# Negative log-likelihood (step: 1630000): 60073.111359
# Negative log-likelihood (step: 1640000): 60429.442859
# Negative log-likelihood (step: 1650000): 59327.608385
# Negative log-likelihood (step: 1660000): 57198.519111
# Negative log-likelihood (step: 1670000): 57105.034344
# Negative log-likelihood (step: 1680000): 60059.963170
# Negative log-likelihood (step: 1690000): 60091.909314
# Negative log-likelihood (step: 1700000): 54692.400514
# Negative log-likelihood (step: 1710000): 59625.626180
# Negative log-likelihood (step: 1720000): 59398.058082
# Negative log-likelihood (step: 1730000): 60173.207177
# Negative log-likelihood (step: 1740000): 56330.280481
# Negative log-likelihood (step: 1750000): 57817.235094
# Negative log-likelihood (step: 1760000): 60042.129850
# Negative log-likelihood (step: 1770000): 59415.705669
# Negative log-likelihood (step: 1780000): 59304.256008
# Negative log-likelihood (step: 1790000): 58692.636559
# Negative log-likelihood (step: 1800000): 59403.957707
# Negative log-likelihood (step: 1810000): 59383.989821
# Negative log-likelihood (step: 1820000): 58064.247709
# Negative log-likelihood (step: 1830000): 56752.207904
# Negative log-likelihood (step: 1840000): 59009.293636
# Negative log-likelihood (step: 1850000): 59185.488123
# Negative log-likelihood (step: 1860000): 56214.906363
# Negative log-likelihood (step: 1870000): 59228.771639
# Negative log-likelihood (step: 1880000): 59058.742872
# Negative log-likelihood (step: 1890000): 55869.367773
# Negative log-likelihood (step: 1900000): 59552.072403
# Negative log-likelihood (step: 1910000): 58145.557743
# Negative log-likelihood (step: 1920000): 57643.316314
# Negative log-likelihood (step: 1930000): 59565.144984
# Negative log-likelihood (step: 1940000): 57079.270423
# Negative log-likelihood (step: 1950000): 55885.624251
# Negative log-likelihood (step: 1960000): 55899.128249
# Negative log-likelihood (step: 1970000): 58287.583030
# Negative log-likelihood (step: 1980000): 54288.769335
# Negative log-likelihood (step: 1990000): 58788.268322
# Negative log-likelihood (step: 2000000): 58772.886453
# Negative log-likelihood (step: 2010000): 56392.494516
# Negative log-likelihood (step: 2020000): 60388.974561
# Negative log-likelihood (step: 2030000): 59300.159367
# Negative log-likelihood (step: 2040000): 59629.333248
# Negative log-likelihood (step: 2050000): 59795.873953
# Negative log-likelihood (step: 2060000): 56938.941450
# Negative log-likelihood (step: 2070000): 56864.875171
# Negative log-likelihood (step: 2080000): 56467.024875
# Negative log-likelihood (step: 2090000): 58983.638432
# Negative log-likelihood (step: 2100000): 59227.132625
# Negative log-likelihood (step: 2110000): 57531.334009
# Negative log-likelihood (step: 2120000): 57141.692138
# Negative log-likelihood (step: 2130000): 57489.130431
# Negative log-likelihood (step: 2140000): 55422.305307
# Negative log-likelihood (step: 2150000): 57837.476385
# Negative log-likelihood (step: 2160000): 57178.548092
# Negative log-likelihood (step: 2170000): 58445.417231
# Negative log-likelihood (step: 2180000): 56995.286591
# Negative log-likelihood (step: 2190000): 59054.368895
# Negative log-likelihood (step: 2200000): 57372.070302
# Negative log-likelihood (step: 2210000): 58187.082253
# Negative log-likelihood (step: 2220000): 57511.517175
# Negative log-likelihood (step: 2230000): 58315.965306
# Negative log-likelihood (step: 2240000): 58647.679612
# Negative log-likelihood (step: 2250000): 57059.526274
# Negative log-likelihood (step: 2260000): 55740.601741
# Negative log-likelihood (step: 2270000): 58831.792064
# Negative log-likelihood (step: 2280000): 57964.237627
# Negative log-likelihood (step: 2290000): 57872.455233
# Negative log-likelihood (step: 2300000): 59430.671834
# Negative log-likelihood (step: 2310000): 58445.834444
# Negative log-likelihood (step: 2320000): 58999.360723
# Negative log-likelihood (step: 2330000): 56586.880768
# Negative log-likelihood (step: 2340000): 56029.329175
# Negative log-likelihood (step: 2350000): 58172.372395
# Negative log-likelihood (step: 2360000): 58549.809205
# Negative log-likelihood (step: 2370000): 58794.450140
# Negative log-likelihood (step: 2380000): 56561.170978
# Negative log-likelihood (step: 2390000): 56369.278306
# Negative log-likelihood (step: 2400000): 56120.753513
# Negative log-likelihood (step: 2410000): 50263.515761
# Negative log-likelihood (step: 2420000): 57747.800359
# Negative log-likelihood (step: 2430000): 59580.332864
# Negative log-likelihood (step: 2440000): 56939.446112
# Negative log-likelihood (step: 2450000): 57605.057727
# Negative log-likelihood (step: 2460000): 57081.330578
# Negative log-likelihood (step: 2470000): 59082.073687
# Negative log-likelihood (step: 2480000): 56033.298118
# Negative log-likelihood (step: 2490000): 58572.239951
# Negative log-likelihood (step: 2500000): 56092.521368
# Negative log-likelihood (step: 2510000): 56143.007582
# Negative log-likelihood (step: 2520000): 58038.754192
# Negative log-likelihood (step: 2530000): 57425.039586
# Negative log-likelihood (step: 2540000): 56485.226519
# Negative log-likelihood (step: 2550000): 56781.791968
# Negative log-likelihood (step: 2560000): 54285.157792
# Negative log-likelihood (step: 2570000): 58726.294568
# Negative log-likelihood (step: 2580000): 55903.711978
# Negative log-likelihood (step: 2590000): 54536.637435
# Negative log-likelihood (step: 2600000): 56005.577137
# Negative log-likelihood (step: 2610000): 58615.594621
# Negative log-likelihood (step: 2620000): 57382.323905
# Negative log-likelihood (step: 2630000): 54465.926149
# Negative log-likelihood (step: 2640000): 57828.532283
# Negative log-likelihood (step: 2650000): 56026.955686
# Negative log-likelihood (step: 2660000): 56130.073082
# Negative log-likelihood (step: 2670000): 55139.091281
# Negative log-likelihood (step: 2680000): 58458.439473
# Negative log-likelihood (step: 2690000): 57610.076595
# Negative log-likelihood (step: 2700000): 56800.057891
# Negative log-likelihood (step: 2710000): 57067.969545
# Negative log-likelihood (step: 2720000): 56916.937919
# Negative log-likelihood (step: 2730000): 55949.201677
# Negative log-likelihood (step: 2740000): 59164.215217
# Negative log-likelihood (step: 2750000): 57252.624865
# Negative log-likelihood (step: 2760000): 57522.404334
# Negative log-likelihood (step: 2770000): 58370.236419
# Negative log-likelihood (step: 2780000): 56521.232480
# Negative log-likelihood (step: 2790000): 57094.561088
# Negative log-likelihood (step: 2800000): 55732.534117
# Negative log-likelihood (step: 2810000): 55904.763640
# Negative log-likelihood (step: 2820000): 57421.023123
# Negative log-likelihood (step: 2830000): 56138.366863
# Negative log-likelihood (step: 2840000): 56687.146493
# Negative log-likelihood (step: 2850000): 57082.884094
# Negative log-likelihood (step: 2860000): 57792.523905
# Negative log-likelihood (step: 2870000): 53144.549068
# Negative log-likelihood (step: 2880000): 57962.208369
# Negative log-likelihood (step: 2890000): 56044.538118
# Negative log-likelihood (step: 2900000): 55747.384195
# Negative log-likelihood (step: 2910000): 56365.227436
# Negative log-likelihood (step: 2920000): 58911.485869
# Negative log-likelihood (step: 2930000): 56626.665691
# Negative log-likelihood (step: 2940000): 58125.329591
# Negative log-likelihood (step: 2950000): 57600.940620
# Negative log-likelihood (step: 2960000): 54640.417188
# Negative log-likelihood (step: 2970000): 53192.172409
# Negative log-likelihood (step: 2980000): 55648.288607
# Negative log-likelihood (step: 2990000): 57112.078476
# Negative log-likelihood (step: 3000000): 57304.639888
# Negative log-likelihood (step: 3010000): 56987.663524
# Negative log-likelihood (step: 3020000): 54076.088918
# Negative log-likelihood (step: 3030000): 56431.849677
# Negative log-likelihood (step: 3040000): 57447.751440
# Negative log-likelihood (step: 3050000): 57476.703438
# Negative log-likelihood (step: 3060000): 57111.456424
# Negative log-likelihood (step: 3070000): 59418.897950
# Negative log-likelihood (step: 3080000): 58822.851010
# Negative log-likelihood (step: 3090000): 49227.557877
# Negative log-likelihood (step: 3100000): 59024.429006
# Negative log-likelihood (step: 3110000): 57544.589403
# Negative log-likelihood (step: 3120000): 56152.639542
# Negative log-likelihood (step: 3130000): 58384.484878
# Negative log-likelihood (step: 3140000): 57958.910341
# Negative log-likelihood (step: 3150000): 54975.269841
# Negative log-likelihood (step: 3160000): 54427.945015
# Negative log-likelihood (step: 3170000): 56929.491626
# Negative log-likelihood (step: 3180000): 57510.903609
# Negative log-likelihood (step: 3190000): 56075.472267
# Negative log-likelihood (step: 3200000): 55648.658619
# Negative log-likelihood (step: 3210000): 56789.908605
# Negative log-likelihood (step: 3220000): 56110.923084
# Negative log-likelihood (step: 3230000): 58743.220814
# Negative log-likelihood (step: 3240000): 57753.309669
# Negative log-likelihood (step: 3250000): 54729.256656
# Negative log-likelihood (step: 3260000): 57114.134546
# Negative log-likelihood (step: 3270000): 58377.829804
# Negative log-likelihood (step: 3280000): 56380.088496
# Negative log-likelihood (step: 3290000): 55831.224338
# Negative log-likelihood (step: 3300000): 56014.136045
# Negative log-likelihood (step: 3310000): 57341.814941
# Negative log-likelihood (step: 3320000): 57031.678779
# Negative log-likelihood (step: 3330000): 57934.599131
# Negative log-likelihood (step: 3340000): 58178.220826
# Negative log-likelihood (step: 3350000): 58459.538044
# Negative log-likelihood (step: 3360000): 58155.725449
# Negative log-likelihood (step: 3370000): 56363.969112
# Negative log-likelihood (step: 3380000): 58022.779512
# Negative log-likelihood (step: 3390000): 56739.235378
# Negative log-likelihood (step: 3400000): 57438.566645
# Negative log-likelihood (step: 3410000): 56471.823877
# Negative log-likelihood (step: 3420000): 56334.544547
# Negative log-likelihood (step: 3430000): 57799.439757
# Negative log-likelihood (step: 3440000): 57797.079699
# Negative log-likelihood (step: 3450000): 57634.751603
# Negative log-likelihood (step: 3460000): 53631.372096
# Negative log-likelihood (step: 3470000): 55242.232482
# Negative log-likelihood (step: 3480000): 57945.419034
# Negative log-likelihood (step: 3490000): 56042.412468
# Negative log-likelihood (step: 3500000): 56071.312747
# Negative log-likelihood (step: 3510000): 57741.356719
# Negative log-likelihood (step: 3520000): 56146.819000
# Negative log-likelihood (step: 3530000): 56418.963357
# Negative log-likelihood (step: 3540000): 55526.489486
# Negative log-likelihood (step: 3550000): 57779.880407
# Negative log-likelihood (step: 3560000): 54862.371216
# Negative log-likelihood (step: 3570000): 57479.490348
# Negative log-likelihood (step: 3580000): 56805.766247
# Negative log-likelihood (step: 3590000): 59120.097256
# Negative log-likelihood (step: 3600000): 56384.756498
# Negative log-likelihood (step: 3610000): 57856.584462
# Negative log-likelihood (step: 3620000): 56443.246714
# Negative log-likelihood (step: 3630000): 58133.471703
# Negative log-likelihood (step: 3640000): 50773.787523
# Negative log-likelihood (step: 3650000): 54059.782702
# Negative log-likelihood (step: 3660000): 55179.268494
# Negative log-likelihood (step: 3670000): 55872.909037
# Negative log-likelihood (step: 3680000): 57232.940772
# Negative log-likelihood (step: 3690000): 58092.950386
# Negative log-likelihood (step: 3700000): 56347.203915
# Negative log-likelihood (step: 3710000): 57496.061425
# Negative log-likelihood (step: 3720000): 56374.829528
# Negative log-likelihood (step: 3730000): 58030.091566
# Negative log-likelihood (step: 3740000): 56195.899219
# Negative log-likelihood (step: 3750000): 55889.808691
# Negative log-likelihood (step: 3760000): 56637.707581
# Negative log-likelihood (step: 3770000): 55897.053519
# Negative log-likelihood (step: 3780000): 57657.783240
# Negative log-likelihood (step: 3790000): 57978.535475
# Negative log-likelihood (step: 3800000): 56765.154753
# Negative log-likelihood (step: 3810000): 56654.242429
# Negative log-likelihood (step: 3820000): 55288.835463
# Negative log-likelihood (step: 3830000): 55832.522288
# Negative log-likelihood (step: 3840000): 56048.925380
# Negative log-likelihood (step: 3850000): 57198.524118
# Negative log-likelihood (step: 3860000): 56639.591411
# Negative log-likelihood (step: 3870000): 55275.075174
# Negative log-likelihood (step: 3880000): 55133.597857
# Negative log-likelihood (step: 3890000): 55204.726969
# Negative log-likelihood (step: 3900000): 57166.963105
# Negative log-likelihood (step: 3910000): 55156.138615
# Negative log-likelihood (step: 3920000): 55381.273581
# Negative log-likelihood (step: 3930000): 54670.151297
# Negative log-likelihood (step: 3940000): 57405.349628
# Negative log-likelihood (step: 3950000): 57685.477414
# Negative log-likelihood (step: 3960000): 57060.043840
# Negative log-likelihood (step: 3970000): 58286.273165
# Negative log-likelihood (step: 3980000): 56701.594850
# Negative log-likelihood (step: 3990000): 57262.586304
# Negative log-likelihood (step: 4000000): 57300.680213
# Negative log-likelihood (step: 4010000): 53054.011961
# Negative log-likelihood (step: 4020000): 48914.906283
# Negative log-likelihood (step: 4030000): 56644.523886
# Negative log-likelihood (step: 4040000): 54763.871008
# Negative log-likelihood (step: 4050000): 55856.900017
# Negative log-likelihood (step: 4060000): 55383.576201
# Negative log-likelihood (step: 4070000): 53476.294618
# Negative log-likelihood (step: 4080000): 55091.934621
# Negative log-likelihood (step: 4090000): 56751.897229
# Negative log-likelihood (step: 4100000): 56835.086092
# Negative log-likelihood (step: 4110000): 54569.569297
# Negative log-likelihood (step: 4120000): 56578.974987
# Negative log-likelihood (step: 4130000): 56350.193569
# Negative log-likelihood (step: 4140000): 58122.174697
# Negative log-likelihood (step: 4150000): 56649.447861
# Negative log-likelihood (step: 4160000): 56059.764963
# Negative log-likelihood (step: 4170000): 57674.663132
# Negative log-likelihood (step: 4180000): 57459.517052
# Negative log-likelihood (step: 4190000): 53579.590876
# Negative log-likelihood (step: 4200000): 56637.454785
# Negative log-likelihood (step: 4210000): 57590.550742
# Negative log-likelihood (step: 4220000): 52071.323159
# Negative log-likelihood (step: 4230000): 56866.534917
# Negative log-likelihood (step: 4240000): 58583.234931
# Negative log-likelihood (step: 4250000): 57289.293860
# Negative log-likelihood (step: 4260000): 55438.969561
# Negative log-likelihood (step: 4270000): 55645.073159
# Negative log-likelihood (step: 4280000): 55231.458529
# Negative log-likelihood (step: 4290000): 56685.786031
# Negative log-likelihood (step: 4300000): 54312.832323
# Negative log-likelihood (step: 4310000): 56315.376998
# Negative log-likelihood (step: 4320000): 55073.614437
# Negative log-likelihood (step: 4330000): 53086.963170
# Negative log-likelihood (step: 4340000): 58221.969545
# Negative log-likelihood (step: 4350000): 56774.182336
# Negative log-likelihood (step: 4360000): 58052.361672
# Negative log-likelihood (step: 4370000): 53898.100654
# Negative log-likelihood (step: 4380000): 56628.244863
# Negative log-likelihood (step: 4390000): 56310.910858
# Negative log-likelihood (step: 4400000): 56398.553705
# Negative log-likelihood (step: 4410000): 56071.838722
# Negative log-likelihood (step: 4420000): 56808.559004
# Negative log-likelihood (step: 4430000): 55301.082455
# Negative log-likelihood (step: 4440000): 57050.844139
# Negative log-likelihood (step: 4450000): 57784.119578
# Negative log-likelihood (step: 4460000): 57205.023145
# Negative log-likelihood (step: 4470000): 57343.907749
# Negative log-likelihood (step: 4480000): 55632.898142
# Negative log-likelihood (step: 4490000): 56645.696958
# Negative log-likelihood (step: 4500000): 54568.984293
# Negative log-likelihood (step: 4510000): 57469.965729
# Negative log-likelihood (step: 4520000): 57494.276630
# Negative log-likelihood (step: 4530000): 56152.122743
# Negative log-likelihood (step: 4540000): 55151.516300
# Negative log-likelihood (step: 4550000): 56814.508054
# Negative log-likelihood (step: 4560000): 57944.809396
# Negative log-likelihood (step: 4570000): 55787.950778
# Negative log-likelihood (step: 4580000): 57146.902100
# Negative log-likelihood (step: 4590000): 55682.862956
# Negative log-likelihood (step: 4600000): 55579.078320
# Negative log-likelihood (step: 4610000): 56212.585240
# Negative log-likelihood (step: 4620000): 56742.764149
# Negative log-likelihood (step: 4630000): 57385.461576
# Negative log-likelihood (step: 4640000): 56082.127666
# Negative log-likelihood (step: 4650000): 54686.784068
# Negative log-likelihood (step: 4660000): 53819.719555
# Negative log-likelihood (step: 4670000): 56707.488312
# Negative log-likelihood (step: 4680000): 55306.040515
# Negative log-likelihood (step: 4690000): 54763.691672
# Negative log-likelihood (step: 4700000): 56405.612906
# Negative log-likelihood (step: 4710000): 54285.255046
# Negative log-likelihood (step: 4720000): 56929.183319
# Negative log-likelihood (step: 4730000): 53749.021747
# Negative log-likelihood (step: 4740000): 56099.113609
# Negative log-likelihood (step: 4750000): 53614.397967
# Negative log-likelihood (step: 4760000): 56763.987571
# Negative log-likelihood (step: 4770000): 56068.244021
# Negative log-likelihood (step: 4780000): 53528.037089
# Negative log-likelihood (step: 4790000): 54226.666457
# Negative log-likelihood (step: 4800000): 56885.021664
# Negative log-likelihood (step: 4810000): 55132.709220
# Negative log-likelihood (step: 4820000): 57683.626730
# Negative log-likelihood (step: 4830000): 55916.637865
# Negative log-likelihood (step: 4840000): 56938.556971
# Negative log-likelihood (step: 4850000): 55686.877123
# Negative log-likelihood (step: 4860000): 55331.247069
# Negative log-likelihood (step: 4870000): 57449.760963
# Negative log-likelihood (step: 4880000): 57100.854071
# Negative log-likelihood (step: 4890000): 56000.025259
# Negative log-likelihood (step: 4900000): 53468.454859
# Negative log-likelihood (step: 4910000): 56520.783820
# Negative log-likelihood (step: 4920000): 55878.281655
# Negative log-likelihood (step: 4930000): 55941.735322
# Negative log-likelihood (step: 4940000): 57647.080568
# Negative log-likelihood (step: 4950000): 55867.493631
# Negative log-likelihood (step: 4960000): 56047.739689
# Negative log-likelihood (step: 4970000): 55139.010514
# Negative log-likelihood (step: 4980000): 57323.733624
# Negative log-likelihood (step: 4990000): 56752.983258
# Negative log-likelihood (step: 5000000): 57549.261230
# Negative log-likelihood (step: 5010000): 55747.400122
# Negative log-likelihood (step: 5020000): 54280.022484
# Negative log-likelihood (step: 5030000): 57977.072141
# Negative log-likelihood (step: 5040000): 56906.670986
# Negative log-likelihood (step: 5050000): 57647.477831
# Negative log-likelihood (step: 5060000): 56561.753950
# Negative log-likelihood (step: 5070000): 56987.569685
# Negative log-likelihood (step: 5080000): 56406.589939
# Negative log-likelihood (step: 5090000): 57620.177922
# Negative log-likelihood (step: 5100000): 56121.645111
# Negative log-likelihood (step: 5110000): 55373.575155
# Negative log-likelihood (step: 5120000): 56870.631722
# Negative log-likelihood (step: 5130000): 58770.421452
# Negative log-likelihood (step: 5140000): 57120.785165
# Negative log-likelihood (step: 5150000): 56369.843171
# Negative log-likelihood (step: 5160000): 54280.081303
# Negative log-likelihood (step: 5170000): 56251.675617
# Negative log-likelihood (step: 5180000): 57456.356678
# Negative log-likelihood (step: 5190000): 56609.206136
# Negative log-likelihood (step: 5200000): 56586.832546
# Negative log-likelihood (step: 5210000): 55641.100287
# Negative log-likelihood (step: 5220000): 53462.471495
# Negative log-likelihood (step: 5230000): 54140.364078
# Negative log-likelihood (step: 5240000): 55046.161111
# Negative log-likelihood (step: 5250000): 56552.539788
# Negative log-likelihood (step: 5260000): 55103.579284
# Negative log-likelihood (step: 5270000): 56717.760540
# Negative log-likelihood (step: 5280000): 54793.961500
# Negative log-likelihood (step: 5290000): 56896.611427
# Negative log-likelihood (step: 5300000): 55758.711406
# Negative log-likelihood (step: 5310000): 56271.439546
# Negative log-likelihood (step: 5320000): 56582.082864
# Negative log-likelihood (step: 5330000): 57055.910563
# Negative log-likelihood (step: 5340000): 55183.310615
# Negative log-likelihood (step: 5350000): 56356.729666
# Negative log-likelihood (step: 5360000): 56194.221985
# Negative log-likelihood (step: 5370000): 54050.470573
# Negative log-likelihood (step: 5380000): 56376.276612
# Negative log-likelihood (step: 5390000): 53643.512033
# Negative log-likelihood (step: 5400000): 53619.455204
# Negative log-likelihood (step: 5410000): 56370.369943
# Negative log-likelihood (step: 5420000): 57527.498604
# Negative log-likelihood (step: 5430000): 54834.847371
# Negative log-likelihood (step: 5440000): 54385.216140
# Negative log-likelihood (step: 5450000): 55682.689880
# Negative log-likelihood (step: 5460000): 57846.595992
# Negative log-likelihood (step: 5470000): 56744.682704
# Negative log-likelihood (step: 5480000): 57256.583517
# Negative log-likelihood (step: 5490000): 55007.420171
# Negative log-likelihood (step: 5500000): 54164.359691
# Negative log-likelihood (step: 5510000): 55824.034528
# Negative log-likelihood (step: 5520000): 56046.045393
# Negative log-likelihood (step: 5530000): 55827.746609
# Negative log-likelihood (step: 5540000): 55742.597831
# Negative log-likelihood (step: 5550000): 55885.191055
# Negative log-likelihood (step: 5560000): 56849.049546
# Negative log-likelihood (step: 5570000): 56613.395903
# Negative log-likelihood (step: 5580000): 52854.364571
# Negative log-likelihood (step: 5590000): 54379.815214
# Negative log-likelihood (step: 5600000): 57451.593479
# Negative log-likelihood (step: 5610000): 56481.737375
# Negative log-likelihood (step: 5620000): 53612.888484
# Negative log-likelihood (step: 5630000): 52360.004060
# Negative log-likelihood (step: 5640000): 55233.716124
# Negative log-likelihood (step: 5650000): 51374.149923
# Negative log-likelihood (step: 5660000): 55287.061707
# Negative log-likelihood (step: 5670000): 56113.616997
# Negative log-likelihood (step: 5680000): 57115.464061
# Negative log-likelihood (step: 5690000): 53934.726589
# Negative log-likelihood (step: 5700000): 55518.003372
# Negative log-likelihood (step: 5710000): 52237.050157
# Negative log-likelihood (step: 5720000): 58159.500242
# Negative log-likelihood (step: 5730000): 55465.027540
# Negative log-likelihood (step: 5740000): 57240.489299
# Negative log-likelihood (step: 5750000): 56446.364282
# Negative log-likelihood (step: 5760000): 52591.423322
# Negative log-likelihood (step: 5770000): 54161.912254
# Negative log-likelihood (step: 5780000): 56859.326639
# Negative log-likelihood (step: 5790000): 57332.698410
# Negative log-likelihood (step: 5800000): 53717.652627
# Negative log-likelihood (step: 5810000): 56365.895885
# Negative log-likelihood (step: 5820000): 55898.723204
# Negative log-likelihood (step: 5830000): 54824.156521
# Negative log-likelihood (step: 5840000): 52310.322533
# Negative log-likelihood (step: 5850000): 55573.835412
# Negative log-likelihood (step: 5860000): 55089.031311
# Negative log-likelihood (step: 5870000): 56458.731207
# Negative log-likelihood (step: 5880000): 55954.290321
# Negative log-likelihood (step: 5890000): 54794.877106
# Negative log-likelihood (step: 5900000): 56407.300872
# Negative log-likelihood (step: 5910000): 53934.921474
# Negative log-likelihood (step: 5920000): 54808.823482
# Negative log-likelihood (step: 5930000): 58126.622126
# Negative log-likelihood (step: 5940000): 52624.626707
# Negative log-likelihood (step: 5950000): 57504.923503
# Negative log-likelihood (step: 5960000): 53954.335656
# Negative log-likelihood (step: 5970000): 53668.015412
# Negative log-likelihood (step: 5980000): 55587.400630
# Negative log-likelihood (step: 5990000): 54997.298473
# Negative log-likelihood (step: 6000000): 56281.237803
# Negative log-likelihood (step: 6010000): 54557.955417
# Negative log-likelihood (step: 6020000): 56940.547636
# Negative log-likelihood (step: 6030000): 53084.626961
# Negative log-likelihood (step: 6040000): 56610.468319
# Negative log-likelihood (step: 6050000): 56240.168642
# Negative log-likelihood (step: 6060000): 55175.933288
# Negative log-likelihood (step: 6070000): 55673.980294
# Negative log-likelihood (step: 6080000): 57310.941531
# Negative log-likelihood (step: 6090000): 55834.925485
# Negative log-likelihood (step: 6100000): 57425.073433
# Negative log-likelihood (step: 6110000): 56665.001137
# Negative log-likelihood (step: 6120000): 55974.530152
# Negative log-likelihood (step: 6130000): 57108.551622
# Negative log-likelihood (step: 6140000): 53898.786687
# Negative log-likelihood (step: 6150000): 53209.524634
# Negative log-likelihood (step: 6160000): 52714.285232
# Negative log-likelihood (step: 6170000): 53767.694005
# Negative log-likelihood (step: 6180000): 56638.637906
# Negative log-likelihood (step: 6190000): 55307.613981
# Negative log-likelihood (step: 6200000): 56366.029121
# Negative log-likelihood (step: 6210000): 51034.116052
# Negative log-likelihood (step: 6220000): 56566.066765
# Negative log-likelihood (step: 6230000): 56476.592548
# Negative log-likelihood (step: 6240000): 56821.440770
# Negative log-likelihood (step: 6250000): 54484.530329
# Negative log-likelihood (step: 6260000): 55332.202878
# Negative log-likelihood (step: 6270000): 54135.184432
# Negative log-likelihood (step: 6280000): 52776.604434
# Negative log-likelihood (step: 6290000): 49349.173209
# Negative log-likelihood (step: 6300000): 48833.334165
# Negative log-likelihood (step: 6310000): 56434.756951
# Negative log-likelihood (step: 6320000): 56169.305347
# Negative log-likelihood (step: 6330000): 55051.848744
# Negative log-likelihood (step: 6340000): 57103.802132
# Negative log-likelihood (step: 6350000): 56462.271742
# Negative log-likelihood (step: 6360000): 55260.527802
# Negative log-likelihood (step: 6370000): 56232.218165
# Negative log-likelihood (step: 6380000): 57590.328503
# Negative log-likelihood (step: 6390000): 56446.389511
# Negative log-likelihood (step: 6400000): 56231.339264
# Negative log-likelihood (step: 6410000): 54638.137946
# Negative log-likelihood (step: 6420000): 56801.843216
# Negative log-likelihood (step: 6430000): 54968.165408
# Negative log-likelihood (step: 6440000): 56510.877556
# Negative log-likelihood (step: 6450000): 56268.965866
# Negative log-likelihood (step: 6460000): 56711.354840
# Negative log-likelihood (step: 6470000): 54622.918129
# Negative log-likelihood (step: 6480000): 55275.183451
# Negative log-likelihood (step: 6490000): 55436.323482
# Negative log-likelihood (step: 6500000): 53553.284763
# Negative log-likelihood (step: 6510000): 50760.894783
# Negative log-likelihood (step: 6520000): 55890.358480
# Negative log-likelihood (step: 6530000): 57123.559638
# Negative log-likelihood (step: 6540000): 55502.081604
# Negative log-likelihood (step: 6550000): 56424.945060
# Negative log-likelihood (step: 6560000): 55143.173855
# Negative log-likelihood (step: 6570000): 56823.450875
# Negative log-likelihood (step: 6580000): 56034.610126
# Negative log-likelihood (step: 6590000): 55772.108008
# Negative log-likelihood (step: 6600000): 54524.283425
# Negative log-likelihood (step: 6610000): 53941.392505
# Negative log-likelihood (step: 6620000): 55591.764184
# Negative log-likelihood (step: 6630000): 50127.518752
# Negative log-likelihood (step: 6640000): 47172.086368
# Negative log-likelihood (step: 6650000): 53456.537828
# Negative log-likelihood (step: 6660000): 52202.859674
# Negative log-likelihood (step: 6670000): 56623.794223
# Negative log-likelihood (step: 6680000): 51248.907376
# Negative log-likelihood (step: 6690000): 52693.725765
# Negative log-likelihood (step: 6700000): 55986.227602
# Negative log-likelihood (step: 6710000): 57007.568525
# Negative log-likelihood (step: 6720000): 55712.849102
# Negative log-likelihood (step: 6730000): 56084.884857
# Negative log-likelihood (step: 6740000): 56516.829986
# Negative log-likelihood (step: 6750000): 56844.658083
# Negative log-likelihood (step: 6760000): 57037.911083
# Negative log-likelihood (step: 6770000): 58375.155491
# Negative log-likelihood (step: 6780000): 55347.600889
# Negative log-likelihood (step: 6790000): 55796.982516
# Negative log-likelihood (step: 6800000): 55645.707764
# Negative log-likelihood (step: 6810000): 56352.963787
# Negative log-likelihood (step: 6820000): 54185.743097
# Negative log-likelihood (step: 6830000): 56507.028506
# Negative log-likelihood (step: 6840000): 54198.670771
# Negative log-likelihood (step: 6850000): 54273.705045
# Negative log-likelihood (step: 6860000): 56030.788832
# Negative log-likelihood (step: 6870000): 55423.355275
# Negative log-likelihood (step: 6880000): 54376.800923
# Negative log-likelihood (step: 6890000): 55940.905116
# Negative log-likelihood (step: 6900000): 54689.688059
# Negative log-likelihood (step: 6910000): 57049.355702
# Negative log-likelihood (step: 6920000): 54424.654938
# Negative log-likelihood (step: 6930000): 55622.867519
# Negative log-likelihood (step: 6940000): 55395.664449
# Negative log-likelihood (step: 6950000): 56099.434258
# Negative log-likelihood (step: 6960000): 54136.281378
# Negative log-likelihood (step: 6970000): 54878.662120
# Negative log-likelihood (step: 6980000): 55198.736996
# Negative log-likelihood (step: 6990000): 55272.764002
# Negative log-likelihood (step: 7000000): 54554.941312
# Negative log-likelihood (step: 7010000): 56926.055984
# Negative log-likelihood (step: 7020000): 55252.170430
# Negative log-likelihood (step: 7030000): 56458.744975
# Negative log-likelihood (step: 7040000): 57793.016958
# Negative log-likelihood (step: 7050000): 56715.871583
# Negative log-likelihood (step: 7060000): 55756.667224
# Negative log-likelihood (step: 7070000): 54911.868642
# Negative log-likelihood (step: 7080000): 53813.484799
# Negative log-likelihood (step: 7090000): 57366.559230
# Negative log-likelihood (step: 7100000): 55195.601445
# Negative log-likelihood (step: 7110000): 53701.536488
# Negative log-likelihood (step: 7120000): 56124.184329
# Negative log-likelihood (step: 7130000): 54632.660935
# Negative log-likelihood (step: 7140000): 55681.086730
# Negative log-likelihood (step: 7150000): 54209.948678
# Negative log-likelihood (step: 7160000): 54125.571866
# Negative log-likelihood (step: 7170000): 55407.133770
# Negative log-likelihood (step: 7180000): 54696.268435
# Negative log-likelihood (step: 7190000): 54971.099615
# Negative log-likelihood (step: 7200000): 55808.962831
# Negative log-likelihood (step: 7210000): 54548.723348
# Negative log-likelihood (step: 7220000): 55826.944094
# Negative log-likelihood (step: 7230000): 56289.443996
# Negative log-likelihood (step: 7240000): 54587.459128
# Negative log-likelihood (step: 7250000): 56050.466604
# Negative log-likelihood (step: 7260000): 54033.108946
# Negative log-likelihood (step: 7270000): 55092.550793
# Negative log-likelihood (step: 7280000): 52858.850558
# Negative log-likelihood (step: 7290000): 56773.620430
# Negative log-likelihood (step: 7300000): 55280.548192
# Negative log-likelihood (step: 7310000): 56865.221377
# Negative log-likelihood (step: 7320000): 52082.340918
# Negative log-likelihood (step: 7330000): 55592.333053
# Negative log-likelihood (step: 7340000): 56109.478571
# Negative log-likelihood (step: 7350000): 54186.369182
# Negative log-likelihood (step: 7360000): 56440.930804
# Negative log-likelihood (step: 7370000): 53814.376071
# Negative log-likelihood (step: 7380000): 55324.689449
# Negative log-likelihood (step: 7390000): 52870.619791
# Negative log-likelihood (step: 7400000): 55129.108374
# Negative log-likelihood (step: 7410000): 56580.941199
# Negative log-likelihood (step: 7420000): 54495.679749
# Negative log-likelihood (step: 7430000): 53828.711799
# Negative log-likelihood (step: 7440000): 54817.936284
# Negative log-likelihood (step: 7450000): 53299.659534
# Negative log-likelihood (step: 7460000): 54241.785664
# Negative log-likelihood (step: 7470000): 54786.690298
# Negative log-likelihood (step: 7480000): 56647.976259
# Negative log-likelihood (step: 7490000): 56471.904907
# Negative log-likelihood (step: 7500000): 55442.947265
# Negative log-likelihood (step: 7510000): 53542.281840
# Negative log-likelihood (step: 7520000): 56076.647454
# Negative log-likelihood (step: 7530000): 56400.264744
# Negative log-likelihood (step: 7540000): 55374.011762
# Negative log-likelihood (step: 7550000): 54917.806097
# Negative log-likelihood (step: 7560000): 53441.447994
# Negative log-likelihood (step: 7570000): 51111.823632
# Negative log-likelihood (step: 7580000): 54330.697615
# Negative log-likelihood (step: 7590000): 57202.583083
# Negative log-likelihood (step: 7600000): 56693.557768
# Negative log-likelihood (step: 7610000): 55055.386662
# Negative log-likelihood (step: 7620000): 54336.809680
# Negative log-likelihood (step: 7630000): 52705.207934
# Negative log-likelihood (step: 7640000): 54049.576247
# Negative log-likelihood (step: 7650000): 53314.659240
# Negative log-likelihood (step: 7660000): 56176.806272
# Negative log-likelihood (step: 7670000): 48140.820866
# Negative log-likelihood (step: 7680000): 53921.894074
# Negative log-likelihood (step: 7690000): 56798.295099
# Negative log-likelihood (step: 7700000): 53838.898930
# Negative log-likelihood (step: 7710000): 55192.122595
# Negative log-likelihood (step: 7720000): 55371.362071
# Negative log-likelihood (step: 7730000): 57452.130731
# Negative log-likelihood (step: 7740000): 56217.851571
# Negative log-likelihood (step: 7750000): 55003.160419
# Negative log-likelihood (step: 7760000): 53316.264375
# Negative log-likelihood (step: 7770000): 55931.037663
# Negative log-likelihood (step: 7780000): 55568.998500
# Negative log-likelihood (step: 7790000): 56809.479094
# Negative log-likelihood (step: 7800000): 56443.019625
# Negative log-likelihood (step: 7810000): 55535.380235
# Negative log-likelihood (step: 7820000): 50182.910818
# Negative log-likelihood (step: 7830000): 55113.006379
# Negative log-likelihood (step: 7840000): 54354.443370
# Negative log-likelihood (step: 7850000): 56003.248584
# Negative log-likelihood (step: 7860000): 55740.803870
# Negative log-likelihood (step: 7870000): 53769.167277
# Negative log-likelihood (step: 7880000): 53286.090499
# Negative log-likelihood (step: 7890000): 55273.236357
# Negative log-likelihood (step: 7900000): 53570.854498
# Negative log-likelihood (step: 7910000): 56084.692155
# Negative log-likelihood (step: 7920000): 50229.863524
# Negative log-likelihood (step: 7930000): 54907.727275
# Negative log-likelihood (step: 7940000): 54309.448522
# Negative log-likelihood (step: 7950000): 52736.400592
# Negative log-likelihood (step: 7960000): 55719.815509
# Negative log-likelihood (step: 7970000): 54205.467395
# Negative log-likelihood (step: 7980000): 55353.389165
# Negative log-likelihood (step: 7990000): 55380.516248
# Negative log-likelihood (step: 8000000): 53709.564873
# Negative log-likelihood (step: 8010000): 53104.477703
# Negative log-likelihood (step: 8020000): 56107.572658
# Negative log-likelihood (step: 8030000): 55322.761187
# Negative log-likelihood (step: 8040000): 55239.297329
# Negative log-likelihood (step: 8050000): 54478.430469
# Negative log-likelihood (step: 8060000): 55453.828576
# Negative log-likelihood (step: 8070000): 57003.762371
# Negative log-likelihood (step: 8080000): 53164.353313
# Negative log-likelihood (step: 8090000): 53325.721523
# Negative log-likelihood (step: 8100000): 56216.952893
# Negative log-likelihood (step: 8110000): 56759.662364
# Negative log-likelihood (step: 8120000): 55519.212181
# Negative log-likelihood (step: 8130000): 56335.834013
# Negative log-likelihood (step: 8140000): 56538.837092
# Negative log-likelihood (step: 8150000): 55825.807761
# Negative log-likelihood (step: 8160000): 53792.389996
# Negative log-likelihood (step: 8170000): 56811.806223
# Negative log-likelihood (step: 8180000): 56508.235371
# Negative log-likelihood (step: 8190000): 56056.831747
# Negative log-likelihood (step: 8200000): 55428.364832
# Negative log-likelihood (step: 8210000): 56043.950762
# Negative log-likelihood (step: 8220000): 55458.522955
# Negative log-likelihood (step: 8230000): 54172.197052
# Negative log-likelihood (step: 8240000): 54942.854387
# Negative log-likelihood (step: 8250000): 54469.623713
# Negative log-likelihood (step: 8260000): 53678.764322
# Negative log-likelihood (step: 8270000): 54255.522630
# Negative log-likelihood (step: 8280000): 54595.507996
# Negative log-likelihood (step: 8290000): 55217.225483
# Negative log-likelihood (step: 8300000): 56127.663928
# Negative log-likelihood (step: 8310000): 56627.991230
# Negative log-likelihood (step: 8320000): 54510.944519
# Negative log-likelihood (step: 8330000): 54418.103656
# Negative log-likelihood (step: 8340000): 57117.236553
# Negative log-likelihood (step: 8350000): 56452.885201
# Negative log-likelihood (step: 8360000): 57291.670738
# Negative log-likelihood (step: 8370000): 56374.723186
# Negative log-likelihood (step: 8380000): 54041.741181
# Negative log-likelihood (step: 8390000): 53929.846380
# Negative log-likelihood (step: 8400000): 52632.542087
# Negative log-likelihood (step: 8410000): 51512.708827
# Negative log-likelihood (step: 8420000): 53690.254070
# Negative log-likelihood (step: 8430000): 55845.383894
# Negative log-likelihood (step: 8440000): 58227.977042
# Negative log-likelihood (step: 8450000): 54147.584727
# Negative log-likelihood (step: 8460000): 56459.424604
# Negative log-likelihood (step: 8470000): 54160.186492
# Negative log-likelihood (step: 8480000): 54141.405927
# Negative log-likelihood (step: 8490000): 55919.713891
# Negative log-likelihood (step: 8500000): 54441.536593
# Negative log-likelihood (step: 8510000): 54133.096221
# Negative log-likelihood (step: 8520000): 54241.275991
# Negative log-likelihood (step: 8530000): 55719.270152
# Negative log-likelihood (step: 8540000): 54611.791737
# Negative log-likelihood (step: 8550000): 56801.179693
# Negative log-likelihood (step: 8560000): 56026.632849
# Negative log-likelihood (step: 8570000): 55745.488173
# Negative log-likelihood (step: 8580000): 55059.145185
# Negative log-likelihood (step: 8590000): 54624.687834
# Negative log-likelihood (step: 8600000): 54911.080512
# Negative log-likelihood (step: 8610000): 55554.032266
# Negative log-likelihood (step: 8620000): 56432.469636
# Negative log-likelihood (step: 8630000): 49626.375364
# Negative log-likelihood (step: 8640000): 56360.780976
# Negative log-likelihood (step: 8650000): 54922.964824
# Negative log-likelihood (step: 8660000): 51785.986718
# Negative log-likelihood (step: 8670000): 49147.754640
# Negative log-likelihood (step: 8680000): 51858.716127
# Negative log-likelihood (step: 8690000): 54708.502972
# Negative log-likelihood (step: 8700000): 56071.880325
# Negative log-likelihood (step: 8710000): 52656.010749
# Negative log-likelihood (step: 8720000): 54738.091358
# Negative log-likelihood (step: 8730000): 55125.900327
# Negative log-likelihood (step: 8740000): 56961.633225
# ...
# Negative log-likelihood (step: 34340000): 54658.802468
# Negative log-likelihood (step: 34350000): 51657.277205
# Negative log-likelihood (step: 34360000): 54551.686875
# Negative log-likelihood (step: 34370000): 52019.747051
# Negative log-likelihood (step: 34380000): 52334.686136
# Negative log-likelihood (step: 34390000): 55692.512430
# Negative log-likelihood (step: 34400000): 53300.548125
# Negative log-likelihood (step: 34410000): 54486.619485
# Negative log-likelihood (step: 34420000): 55932.882382
# Negative log-likelihood (step: 34430000): 54415.783311
# Negative log-likelihood (step: 34440000): 54479.757419
# Negative log-likelihood (step: 34450000): 50518.399867
# Negative log-likelihood (step: 34460000): 53642.972586
# Negative log-likelihood (step: 34470000): 54243.827524
# Negative log-likelihood (step: 34480000): 52534.889550
# Negative log-likelihood (step: 34490000): 52268.013264
# Negative log-likelihood (step: 34500000): 54042.735498
# Negative log-likelihood (step: 34510000): 54749.162556
# Negative log-likelihood (step: 34520000): 52795.559242
# Negative log-likelihood (step: 34530000): 54597.164820
# Negative log-likelihood (step: 34540000): 54816.309985
# Negative log-likelihood (step: 34550000): 56050.580326
# Negative log-likelihood (step: 34560000): 50635.103512
# Negative log-likelihood (step: 34570000): 48700.268730
# Negative log-likelihood (step: 34580000): 53118.265767
# Negative log-likelihood (step: 34590000): 53382.877935
# Negative log-likelihood (step: 34600000): 53352.420997
# Negative log-likelihood (step: 34610000): 53842.353891
# Negative log-likelihood (step: 34620000): 55132.839999
# Negative log-likelihood (step: 34630000): 50205.123949
# Negative log-likelihood (step: 34640000): 50484.016581
# Negative log-likelihood (step: 34650000): 51983.224664
# Negative log-likelihood (step: 34660000): 53882.308422
# Negative log-likelihood (step: 34670000): 51983.849490
# Negative log-likelihood (step: 34680000): 52765.471134
# Negative log-likelihood (step: 34690000): 52867.277609
# Negative log-likelihood (step: 34700000): 53666.422884
# Negative log-likelihood (step: 34710000): 53917.606468
# Negative log-likelihood (step: 34720000): 53015.916170
# Negative log-likelihood (step: 34730000): 55561.100484
# Negative log-likelihood (step: 34740000): 52813.555346
# Negative log-likelihood (step: 34750000): 54986.446796
# Negative log-likelihood (step: 34760000): 51377.535420
# Negative log-likelihood (step: 34770000): 54369.091625
# Negative log-likelihood (step: 34780000): 50366.406221
# Negative log-likelihood (step: 34790000): 53897.719241
# Negative log-likelihood (step: 34800000): 53165.591194
# Negative log-likelihood (step: 34810000): 49666.610706
# Negative log-likelihood (step: 34820000): 51852.265528
# Negative log-likelihood (step: 34830000): 52673.459478
# Negative log-likelihood (step: 34840000): 52421.383526
# Negative log-likelihood (step: 34850000): 53657.297338
# Negative log-likelihood (step: 34860000): 52299.589308
# Negative log-likelihood (step: 34870000): 53995.569496
# Negative log-likelihood (step: 34880000): 55101.966511
# Negative log-likelihood (step: 34890000): 54109.326690
# Negative log-likelihood (step: 34900000): 54530.031632
# Negative log-likelihood (step: 34910000): 53609.557999
# Negative log-likelihood (step: 34920000): 50440.718849
# Negative log-likelihood (step: 34930000): 51710.039499
# Negative log-likelihood (step: 34940000): 51246.628121
# Negative log-likelihood (step: 34950000): 53802.210230
# Negative log-likelihood (step: 34960000): 53160.004745
# Negative log-likelihood (step: 34970000): 53934.289671
# Negative log-likelihood (step: 34980000): 49752.176334
# Negative log-likelihood (step: 34990000): 51710.258766
# Negative log-likelihood (step: 35000000): 54016.716752
# Negative log-likelihood (step: 35010000): 55663.409295
# Negative log-likelihood (step: 35020000): 55653.228014
# Negative log-likelihood (step: 35030000): 54515.500027
# Negative log-likelihood (step: 35040000): 55291.306101
# Negative log-likelihood (step: 35050000): 52656.546477
# Negative log-likelihood (step: 35060000): 53868.214908
# Negative log-likelihood (step: 35070000): 53648.214233
# Negative log-likelihood (step: 35080000): 54170.129249
# Negative log-likelihood (step: 35090000): 52841.884819
# Negative log-likelihood (step: 35100000): 53958.927868
# Negative log-likelihood (step: 35110000): 55043.399207
# Negative log-likelihood (step: 35120000): 51934.869977
# Negative log-likelihood (step: 35130000): 50839.682081
# Negative log-likelihood (step: 35140000): 52629.380306
# Negative log-likelihood (step: 35150000): 53760.459765
# Negative log-likelihood (step: 35160000): 48836.617534
# Negative log-likelihood (step: 35170000): 54263.023610
# Negative log-likelihood (step: 35180000): 53556.088478
# Negative log-likelihood (step: 35190000): 52584.364296
# Negative log-likelihood (step: 35200000): 50839.630243
# Negative log-likelihood (step: 35210000): 53408.930647
# Negative log-likelihood (step: 35220000): 55630.691194
# Negative log-likelihood (step: 35230000): 55226.454784
# Negative log-likelihood (step: 35240000): 56365.474305
# Negative log-likelihood (step: 35250000): 54069.316940
# Negative log-likelihood (step: 35260000): 55125.125743
# Negative log-likelihood (step: 35270000): 52649.181612
# Negative log-likelihood (step: 35280000): 53796.115734
# Negative log-likelihood (step: 35290000): 53062.627929
# Negative log-likelihood (step: 35300000): 53443.169919
# Negative log-likelihood (step: 35310000): 52915.189420
# Negative log-likelihood (step: 35320000): 49775.947844
# Negative log-likelihood (step: 35330000): 51957.131145
# Negative log-likelihood (step: 35340000): 52483.986570
# Negative log-likelihood (step: 35350000): 55189.316636
# Negative log-likelihood (step: 35360000): 52858.602320
# Negative log-likelihood (step: 35370000): 52670.524107
# Negative log-likelihood (step: 35380000): 53545.273198
# Negative log-likelihood (step: 35390000): 53561.331061
# Negative log-likelihood (step: 35400000): 53371.890683
# Negative log-likelihood (step: 35410000): 54960.911602
# Negative log-likelihood (step: 35420000): 55605.828896
# Negative log-likelihood (step: 35430000): 54984.345948
# Negative log-likelihood (step: 35440000): 53945.589452
# Negative log-likelihood (step: 35450000): 52319.380321
# Negative log-likelihood (step: 35460000): 53067.621325
# Negative log-likelihood (step: 35470000): 51926.095425
# Negative log-likelihood (step: 35480000): 50900.882816
# Negative log-likelihood (step: 35490000): 53010.995418
# Negative log-likelihood (step: 35500000): 55323.090714
# Negative log-likelihood (step: 35510000): 53177.862150
# Negative log-likelihood (step: 35520000): 55335.951747
# Negative log-likelihood (step: 35530000): 54710.803248
# Negative log-likelihood (step: 35540000): 52251.412663
# Negative log-likelihood (step: 35550000): 50350.844127
# Negative log-likelihood (step: 35560000): 55062.883555
# Negative log-likelihood (step: 35570000): 53899.074340
# Negative log-likelihood (step: 35580000): 53497.287450
# Negative log-likelihood (step: 35590000): 53974.762809
# Negative log-likelihood (step: 35600000): 53843.545646
# Negative log-likelihood (step: 35610000): 51832.118269
# Negative log-likelihood (step: 35620000): 54147.605552
# Negative log-likelihood (step: 35630000): 53329.793880
# Negative log-likelihood (step: 35640000): 53043.284162
# Negative log-likelihood (step: 35650000): 53613.201178
# Negative log-likelihood (step: 35660000): 50372.937442
# Negative log-likelihood (step: 35670000): 54530.811571
# Negative log-likelihood (step: 35680000): 52977.899438
# Negative log-likelihood (step: 35690000): 53182.761054
# Negative log-likelihood (step: 35700000): 53804.458383
# Negative log-likelihood (step: 35710000): 51654.448366
# Negative log-likelihood (step: 35720000): 49793.881428
# Negative log-likelihood (step: 35730000): 49608.705152
# Negative log-likelihood (step: 35740000): 53343.877359
# Negative log-likelihood (step: 35750000): 54324.168933
# Negative log-likelihood (step: 35760000): 54462.620485
# Negative log-likelihood (step: 35770000): 56235.717952
# Negative log-likelihood (step: 35780000): 53815.842905
# Negative log-likelihood (step: 35790000): 54709.989404
# Negative log-likelihood (step: 35800000): 55792.782438
# Negative log-likelihood (step: 35810000): 53641.661031
# Negative log-likelihood (step: 35820000): 54540.121120
# Negative log-likelihood (step: 35830000): 53459.140113
# Negative log-likelihood (step: 35840000): 54305.323620
# Negative log-likelihood (step: 35850000): 50790.639588
# Negative log-likelihood (step: 35860000): 52153.824527
# Negative log-likelihood (step: 35870000): 54623.730569
# Negative log-likelihood (step: 35880000): 51352.021034
# Negative log-likelihood (step: 35890000): 54125.193595
# Negative log-likelihood (step: 35900000): 55666.815283
# Negative log-likelihood (step: 35910000): 53128.116348
# Negative log-likelihood (step: 35920000): 54432.556524
# Negative log-likelihood (step: 35930000): 54538.279978
# Negative log-likelihood (step: 35940000): 53087.003415
# Negative log-likelihood (step: 35950000): 54607.839570
# Negative log-likelihood (step: 35960000): 51274.129564
# Negative log-likelihood (step: 35970000): 51894.730025
# Negative log-likelihood (step: 35980000): 52140.262976
# Negative log-likelihood (step: 35990000): 53503.405581
# Negative log-likelihood (step: 36000000): 53550.956045
# Negative log-likelihood (step: 36010000): 54228.068380
# Negative log-likelihood (step: 36020000): 53744.714642
# Negative log-likelihood (step: 36030000): 54166.261441
# Negative log-likelihood (step: 36040000): 53135.737637
# Negative log-likelihood (step: 36050000): 53257.785928
# Negative log-likelihood (step: 36060000): 55349.274376
# Negative log-likelihood (step: 36070000): 54360.418364
# Negative log-likelihood (step: 36080000): 55544.313651
# Negative log-likelihood (step: 36090000): 52228.238809
# Negative log-likelihood (step: 36100000): 53536.438540
# Negative log-likelihood (step: 36110000): 52012.253197
# Negative log-likelihood (step: 36120000): 53776.505581
# Negative log-likelihood (step: 36130000): 53864.366772
# Negative log-likelihood (step: 36140000): 54084.808904
# Negative log-likelihood (step: 36150000): 54274.488657
# Negative log-likelihood (step: 36160000): 52728.828822
# Negative log-likelihood (step: 36170000): 53259.786720
# Negative log-likelihood (step: 36180000): 52526.286200
# Negative log-likelihood (step: 36190000): 54976.925359
# Negative log-likelihood (step: 36200000): 54669.544491
# Negative log-likelihood (step: 36210000): 54821.424909
# Negative log-likelihood (step: 36220000): 55258.603643
# Negative log-likelihood (step: 36230000): 53821.949672
# Negative log-likelihood (step: 36240000): 53084.054349
# Negative log-likelihood (step: 36250000): 53582.567662
# Negative log-likelihood (step: 36260000): 55707.392764
# Negative log-likelihood (step: 36270000): 54083.741669
# Negative log-likelihood (step: 36280000): 52682.996390
# Negative log-likelihood (step: 36290000): 54367.582907
# Negative log-likelihood (step: 36300000): 54554.905176
# Negative log-likelihood (step: 36310000): 54591.601013
# Negative log-likelihood (step: 36320000): 51938.905306
# Negative log-likelihood (step: 36330000): 54003.847256
# Negative log-likelihood (step: 36340000): 52388.223751
# Negative log-likelihood (step: 36350000): 50716.420958
# Negative log-likelihood (step: 36360000): 54009.807039
# Negative log-likelihood (step: 36370000): 51293.137577
# Negative log-likelihood (step: 36380000): 53804.991873
# Negative log-likelihood (step: 36390000): 53697.675129
# Negative log-likelihood (step: 36400000): 51744.653105
# Negative log-likelihood (step: 36410000): 52772.921643
# Negative log-likelihood (step: 36420000): 54264.771872
# Negative log-likelihood (step: 36430000): 53698.332669
# Negative log-likelihood (step: 36440000): 53286.285574
# Negative log-likelihood (step: 36450000): 53564.956185
# Negative log-likelihood (step: 36460000): 54831.611667
# Negative log-likelihood (step: 36470000): 52541.420574
# Negative log-likelihood (step: 36480000): 53414.797348
# Negative log-likelihood (step: 36490000): 52045.474141
# Negative log-likelihood (step: 36500000): 51758.943301
# Negative log-likelihood (step: 36510000): 53462.765493
# Negative log-likelihood (step: 36520000): 54264.490218
# Negative log-likelihood (step: 36530000): 52577.671640
# Negative log-likelihood (step: 36540000): 50144.483715
# Negative log-likelihood (step: 36550000): 51438.673300
# Negative log-likelihood (step: 36560000): 52976.643652
# Negative log-likelihood (step: 36570000): 53202.801856
# Negative log-likelihood (step: 36580000): 52457.254633
# Negative log-likelihood (step: 36590000): 54332.339841
# Negative log-likelihood (step: 36600000): 53117.021192
# Negative log-likelihood (step: 36610000): 51361.141015
# Negative log-likelihood (step: 36620000): 52798.422122
# Negative log-likelihood (step: 36630000): 55118.800513
# Negative log-likelihood (step: 36640000): 53005.844291
# Negative log-likelihood (step: 36650000): 54097.588222
# Negative log-likelihood (step: 36660000): 54986.896950
# Negative log-likelihood (step: 36670000): 54596.189891
# Negative log-likelihood (step: 36680000): 54397.881775
# Negative log-likelihood (step: 36690000): 55486.227882
# Negative log-likelihood (step: 36700000): 52764.430179
# Negative log-likelihood (step: 36710000): 54376.670154
# Negative log-likelihood (step: 36720000): 54377.869672
# Negative log-likelihood (step: 36730000): 54778.232064
# Negative log-likelihood (step: 36740000): 54117.290999
# Negative log-likelihood (step: 36750000): 52727.900833
# Negative log-likelihood (step: 36760000): 52295.537999
# Negative log-likelihood (step: 36770000): 52742.927831
# Negative log-likelihood (step: 36780000): 54029.830940
# Negative log-likelihood (step: 36790000): 54890.739965
# Negative log-likelihood (step: 36800000): 53419.084615
# Negative log-likelihood (step: 36810000): 53726.865093
# Negative log-likelihood (step: 36820000): 54161.703171
# Negative log-likelihood (step: 36830000): 53729.782640
# Negative log-likelihood (step: 36840000): 55061.267538
# Negative log-likelihood (step: 36850000): 54656.948050
# Negative log-likelihood (step: 36860000): 53879.868177
# Negative log-likelihood (step: 36870000): 51412.813702
# Negative log-likelihood (step: 36880000): 55018.217437
# Negative log-likelihood (step: 36890000): 52480.539716
# Negative log-likelihood (step: 36900000): 54154.193106
# Negative log-likelihood (step: 36910000): 55215.207230
# Negative log-likelihood (step: 36920000): 51061.458949
# Negative log-likelihood (step: 36930000): 54560.599117
# Negative log-likelihood (step: 36940000): 51881.874986
# Negative log-likelihood (step: 36950000): 52716.272908
# Negative log-likelihood (step: 36960000): 55235.186362
# Negative log-likelihood (step: 36970000): 53122.728685
# Negative log-likelihood (step: 36980000): 54626.666692
# Negative log-likelihood (step: 36990000): 55993.481979
# Negative log-likelihood (step: 37000000): 55226.309068
# Negative log-likelihood (step: 37010000): 52881.882126
# Negative log-likelihood (step: 37020000): 53890.066041
# Negative log-likelihood (step: 37030000): 53850.295013
# Negative log-likelihood (step: 37040000): 51509.461651
# Negative log-likelihood (step: 37050000): 52451.532266
# Negative log-likelihood (step: 37060000): 53267.907899
# Negative log-likelihood (step: 37070000): 54691.331576
# Negative log-likelihood (step: 37080000): 53337.288462
# Negative log-likelihood (step: 37090000): 53676.805852
# Negative log-likelihood (step: 37100000): 46834.308226
# Negative log-likelihood (step: 37110000): 54160.367111
# Negative log-likelihood (step: 37120000): 52130.710908
# Negative log-likelihood (step: 37130000): 55024.447868
# Negative log-likelihood (step: 37140000): 54741.478426
# Negative log-likelihood (step: 37150000): 53860.427915
# Negative log-likelihood (step: 37160000): 53859.305445
# Negative log-likelihood (step: 37170000): 51843.020628
# Negative log-likelihood (step: 37180000): 53126.358317

# %%
instance.save('trained_vector.txt')

# %%
targets = ["January", "good", "the", "food", "engineering"]

for targ in targets:
    print("Target: ", targ)
    bestpreds = (instance.get_neighbors(targ))
    for pred in bestpreds:
        print(pred["word"], ":", pred["score"])
    print("\n")
# Out:
#   6%|▌         | 6516/108206 [00:00<00:03, 30407.83it/s]
# Target:  January
# 100%|██████████| 108206/108206 [00:02<00:00, 37854.19it/s]
#   6%|▌         | 6104/108206 [00:00<00:03, 28961.85it/s]
# June : 0.9009177653959356
# December : 0.9002343526673667
# May : 0.8931960196336791
# August : 0.888697408531813
# November : 0.8843557200067995
# February : 0.8797365250598626
# October : 0.8795067674627157
# March : 0.8700947144728567
# September : 0.8645465671084334
# July : 0.8446447546192521
#
#
# Target:  good
# 100%|██████████| 108206/108206 [00:03<00:00, 35823.68it/s]
#   6%|▌         | 6409/108206 [00:00<00:03, 30215.16it/s]
# clever : 0.8322196426204818
# superb : 0.8081249289973313
# erudition : 0.7968424625718515
# pleasant : 0.7958439238487498
# fatherly : 0.7804747123760511
# industrious : 0.771689874513083
# attractive : 0.7700174007861669
# unkempt : 0.7691515195600043
# discreet : 0.7688850803047285
# plenty : 0.7649913653393535
#
#
# Target:  the
# 100%|██████████| 108206/108206 [00:02<00:00, 37750.98it/s]
#   3%|▎         | 2793/108206 [00:00<00:03, 27929.09it/s]
# Strait : 0.4129587394761658
# Declaration : 0.40164266090071044
# Disaster : 0.38769319346761333
# reconstitution : 0.38490525664681385
# Gains : 0.38410487081916667
# curated : 0.3839401203143855
# Cases : 0.3828749644135384
# Hurston : 0.3791014402887716
# Riverkeeper : 0.37056072609381685
# collaborators : 0.36909551480443903
#
#
# Target:  food
# 100%|██████████| 108206/108206 [00:02<00:00, 36203.49it/s]
#   6%|▌         | 6473/108206 [00:00<00:03, 29813.45it/s]
# wireless : 0.7996811010624246
# suppliers : 0.7759580444969606
# dough : 0.770453400633206
# cosmetics : 0.7643467394853108
# averse : 0.7636713706325741
# vendors : 0.7632830359195228
# junk : 0.7566509784028933
# chemicals : 0.754046261282496
# inexpensive : 0.7519277513292927
# cooked : 0.748428276536752
#
#
# Target:  engineering
# 100%|██████████| 108206/108206 [00:03<00:00, 35833.75it/s]
# economics : 0.8955100424696705
# biochemistry : 0.8884327852564067
# biophysics : 0.8683646095010252
# meteorology : 0.8547714419440686
# microbiology : 0.8530374524659494
# ophthalmology : 0.8473003277364385
# bacteriology : 0.8463735137712631
# aeronautical : 0.8462152350026217
# biomedical : 0.8424867474694645
# geophysics : 0.8414575750581956

# %%
#Problem 12
import pandas as pd
testfile=pd.read_csv('word_pairs_to_estimate_similarity.test.csv')

# %%
sim=[]
for i in range(len(testfile)):
    sim.append(instance.compute_cosine_similarity(testfile['word1'].loc[i],testfile['word2'].loc[i]))
sim_result=pd.DataFrame({'id':testfile['pair_id'], 'sim':sim})
sim_result.to_csv('result.csv',index=False)
