# %%
import csv
import math
import pickle
import random
import sys
from collections import Counter
import numpy as np

# Hhelpful for computing cosine similarity
from scipy.spatial.distance import cosine

# This will make things go fast when we finally use it
from numba import jit

# Handy command-line argument parsing
import argparse

# Progress bar tracker
from tqdm import tqdm

# Sort of smart tokenization
from nltk.tokenize import RegexpTokenizer

# We'll use this to save our models
from gensim.models import KeyedVectors

# %%
random.seed(1234)
np.random.seed(1234)

# %%
class word2vec:
    def __init__(self, hidden_layer_size=50):

        self.hidden_layer_size = hidden_layer_size
        self.tokenizer = RegexpTokenizer(r'\w+')
        
        # These state variables become populated as the main() function calls
        #
        # 1. load_data()
        # 2. generate_negative_sampling_table()
        # 3. init_weights()
        #
        # See those functions for how the various values get filled in

        self.word_to_index = {} # word to unique-id
        self.index_to_word = [] # unique-id to word

        # How many times each word occurs in our data after filtering
        self.word_counts = Counter()

        # A utility data structure that lets us quickly sample "negative"
        # instances in a context. This table contains unique-ids
        self.negative_sampling_table = []
        
        # The dataset we'll use for training, as a sequence of unqiue word
        # ids. This is the sequence across all documents after tokens have been
        # randomly subsampled by the word2vec preprocessing step
        self.full_token_sequence_as_ids = []

        # These will contain the two weight matrices. W is the embeddings for
        # the center/target word and C are the embeddings for the context
        # words. You might see these called (W, V) or (W1, W2) in various
        # documentation too. These get initalized later in init_weights() once
        # we know the vocabulary size
        self.W = None
        self.C = None
        
    def tokenize(self, text):
        '''
        Tokenize the document and returns a list of the tokens
        '''
        return self.tokenizer.tokenize(text)

        
    def load_data(self, file_name, min_token_freq):
        '''
        Reads the data from the specified file as long long sequence of text
        (ignoring line breaks) and populates the data structures of this
        word2vec object.
        '''

        # Step 1: Read in the file and create a long sequence of tokens
        with open(file_name,"r") as f:   
            original_sequence= f.read()  
        tokens=self.tokenize(original_sequence)
        # Step 2: Count how many tokens we have of each type
        print('Counting token frequencies')
        original_frequency=Counter(tokens)
        

        # Step 3: Replace all tokens below the specified frequency with an <UNK>
        # token
        print("Performing minimum thresholding")
        for i in range(len(tokens)):
            if original_frequency[tokens[i]]<min_token_freq:
                tokens[i]='<UNK>'

        # Step 4: update self.word_counts to be the number of times each word
        # occurs (including <UNK>)
        self.word_counts=Counter(tokens)

        # Step 5: Create the mappings from word to unique integer ID and the
        # reverse mapping.
        #
        # HINT: the id-to-word mapping is easily represented as a list data
        # structure
    
        all_words=list(self.word_counts.keys())
        for i in range(len(all_words)):
            self.word_to_index[all_words[i]]=i
        self.index_to_word=all_words
        
        # Step 6: Compute the probability of keeping any particular token of a
        # word in the training sequence, which we'll use to subsample. This
        # avoids having the training data be filled with many overly common words
        probability={}
        for i in all_words:
            temp_p=self.word_counts[i]/len(tokens)
            #print(temp_p)
            probability[i]=(np.sqrt(temp_p/0.001)+1)*0.001/temp_p
        #print(probability)
        # Step 7: process the list of tokens (after min-freq filtering) to fill
        # a new list self.full_token_sequence_as_ids where (1) we
        # probabilistically choose whether to keep each token based on the
        # subsampling probabilities and (2) all tokens are convered to their
        # unique ids for faster training.
        for i in range(len(tokens)):
            self.full_token_sequence_as_ids.append(self.word_to_index[tokens[i]])
        print(len(tokens))
        # Transform the original input into a sequence of IDs while also
        # performing token-based subsampling based on the probabilities in
        # word_to_sample_prob. This effectively makes the context window larger
        # for some words by removing words that are common from a particular
        # context before the training occurs.
        for i in all_words:
            if probability[i]<1:
                reserve=np.random.binomial(1,probability[i],1)[0]
                if reserve==0:
                    self.full_token_sequence_as_ids=list(filter(lambda x:x!=self.word_to_index[i],self.full_token_sequence_as_ids))

        # self.negative_sampling_table = generate_negative_sampling_table()
        print('Loaded all data from %s; saw %d tokens (%d unique)' \
              % (file_name, len(self.full_token_sequence_as_ids),
                 len(self.word_to_index)))
                
    
    def generate_negative_sampling_table(self, exp_power=0.75, table_size=1e6):
        '''
        Generates a big list data structure that we can quickly randomly index into
        in order to select a negative training example (i.e., a word that was
        *not* present in the context). 
        '''       
        
        # Step 1: Figure out how many instances of each word need to go into the
        # negative sampling table. 
        #
        # HINT: np.power and np.fill might be useful here        
        print("Generating sampling table")
        len_word=[]
        sum_len_word=sum(np.power(list(self.word_counts.values()),exp_power))
        for i in self.index_to_word:
            len_word.append(np.power(self.word_counts[i],exp_power)/sum_len_word)
        len_word=(np.asarray(len_word)*table_size).astype(int)




        print(len(len_word))
        # Step 2: Create the table to the correct size. You'll want this to be a
        # numpy array of type int
        self.negative_sampling_table=np.ones(int(table_size)).astype(int)


        # Step 3: Fill the table so that each word has a number of IDs
        # proportionate to its probability of being sampled.
        #
        # Example: if we have 3 words "a" "b" and "c" with probabilites 0.5,
        # 0.33, 0.16 and a table size of 6 then our table would look like this
        # (before converting the words to IDs):
        #
        # [ "a", "a", "a", "b", "b", "c" ]
        #
        index_temp=0
        sum_temp=0
        #print(len_word)
        for i in range(len(len_word)):
            np.ndarray.fill(self.negative_sampling_table[sum_temp:(sum_temp+len_word[i])],index_temp)
            sum_temp=sum_temp+len_word[i]
            index_temp=index_temp+1


    def generate_negative_samples(self, cur_context_word_id, num_samples):
        '''
        Randomly samples the specified number of negative samples from the lookup
        table and returns this list of IDs as a numpy array. As a performance
        improvement, avoid sampling a negative example that has the same ID as
        the current positive context word.
        '''

        # Step 1: Create a list and sample from the negative_sampling_table to
        # grow the list to num_samples, avoiding adding a negative example that
        # has the same ID as teh current context_word
        results = []
        temp_num_sample=0
        while temp_num_sample<num_samples:
            temp=np.random.choice(self.negative_sampling_table,1)[0]
            if temp!=cur_context_word_id:
                results.append(temp)
                temp_num_sample=temp_num_sample+1
            else:
                pass

        # Step 2: Convert the list of samples to numpy array and return it            
        return np.array(results)
    def save(self, filename):
        '''
        Saves the model to the specified filename as a gensim KeyedVectors in the
        text format so you can load it separately.
        '''

        # Creates an empty KeyedVectors with our embedding size
        kv = KeyedVectors(vector_size=self.hidden_layer_size)        
        vectors = []
        words = []
        # Get the list of words/vectors in a consistent order
        for index, word in enumerate(self.index_to_word): 
            vectors.append(self.W[index].copy())
            words.append(word)
            
        # Fills the KV object with our data in the right order
        kv.add(words, vectors) 
        kv.save_word2vec_format(filename, binary=False)
    def init_weights(self, init_range=0.1):
        '''
        Initializes the weight matrices W (input->hidden) and C (hidden->output)
        by sampling uniformly within a small range around zero.
        '''

        # Step 1: Initialize two numpy arrays (matrices) for W and C by filling
        # their values with a random sample within the speified range.
        #
        # Hint: numpy.random has lots of ways to create matrices for this task
        self.W=np.random.uniform(-init_range,init_range,size=(len(self.word_to_index),self.hidden_layer_size))
        self.C=np.random.uniform(-init_range,init_range,size=(len(self.word_to_index),self.hidden_layer_size))
        
    def train(self, num_epochs=2, window_size=2, num_negative_samples=2,
              learning_rate=0.05, nll_update_iter=10000, max_steps=-1):
        '''
        Trains the word2vec model on the data loaded from load_data for the
        specified number of epochs.
        '''

        # Rather than compute the full negative log-likelihood (NLL), we'll keep
        # a running tally of the nll values for each step and periodically report them
        nll_results = []
        
        # This value keeps track of which step we're on. Since we don't update
        # when the center token is "<UNK>" we may skip over some ids in the
        # inner loop, so we need a separate step count to keep track of how many
        # updates we've done.
        step = 0
        
        # Iterate for the specified number of epochs
        for epoch in range(1, num_epochs+1):
            print("Beginning epoch %d of %d" % (epoch, num_epochs))           
            
            # Step 1: Iterate over each ID in full_token_sequence_as_ids as a center
            # token (skipping those that are <UNK>) and predicting the context
            # word and negative samples
            #
            # Hint: this is a great loop to wrap with a tqdm() call so you can
            # see how long each epoch will take with a progress bar
            overall_length=len(self.full_token_sequence_as_ids)
            for i in range(overall_length):
                center_word=self.full_token_sequence_as_ids[i]
                if self.index_to_word[center_word]=='<UNK>':
                    continue
                if self.index_to_word[center_word] in all_synonyms_words:
                    index_in_synonyms=synonyms_key[self.index_to_word[center_word]]
                try:
                    center_word=self.word_to_index[random.choice(synonyms[index_in_synonyms])]
                   # print('yes')
                except:
                    pass
                window_begin=(i-window_size)
                window_end=(i+1+window_size)
                if window_begin>=0 and window_end<=overall_length:
                    context_word=self.full_token_sequence_as_ids[window_begin:window_begin+2]+self.full_token_sequence_as_ids[window_end-2:window_end]
                elif window_begin<0:
                    context_word=self.full_token_sequence_as_ids[0:window_begin+2]+self.full_token_sequence_as_ids[window_end-2:window_end]
                elif window_end>overall_length:
                    context_word=self.full_token_sequence_as_ids[window_begin:window_begin+2]+self.full_token_sequence_as_ids[window_end-2:overall_length]
                # Periodically print the NLL so we can see how the model is converging
                if nll_update_iter > 0 and step % nll_update_iter == 0 and step > 0 and len(nll_results) > 0:
                    print("Negative log-likelihood (step: %d): %f " % (step, sum(nll_results)))
                    nll_results = []
                                    
                # Step 2: For each word in the window range (before and after)
                # perform an update where we (1) use the current parameters of
                # the model to predict it using the skip-gram task and (2)
                # sample negative instances and predict those. We'll use the
                # values of those predictions (i.e., the output of the sigmoid)
                # to update the W and C matrices using backpropagation.
                #
                # NOTE: this inner loop should call predict_and_backprop() which is
                # defined outside of the class. See note there for why.
                for each_context in context_word:

                    # Step 3: Pick the context word ID
                    

                    # Step 4: Sample negative instances 
                    negative_sample_instances=self.generate_negative_samples(each_context,num_negative_samples)

                    # Step 5: call predict_and_backprop. Don't forget to add the
                    # nll return value to nll_results to keep track of how the
                    # model is learning
                    nll=predict_and_backprop(self.W,self.C,learning_rate,center_word,each_context,negative_sample_instances)
                    nll_results.append(nll)
                    #print(nll_results)

                    
                step += 1
                #print(step)
                if max_steps > 0 and step >= max_steps:
                    break

            if max_steps > 0 and step >= max_steps:
                print('Maximum number of steps reached: %d' % max_steps)
                break
    def get_neighbors(self, target_word):
        """ 
        Finds the top 10 most similar words to a target word
        """
        outputs = []
        for index, word in tqdm(enumerate(self.index_to_word), total=len(self.index_to_word)):
            similarity = self.compute_cosine_similarity(target_word, word)
            result = {"word": word, "score": similarity}
            outputs.append(result)
    
        # Sort by highest scores
        neighbors = sorted(outputs, key=lambda o: o['score'], reverse=True)
        return neighbors[1:11]

    def compute_cosine_similarity(self, word_one, word_two):
        '''
        Computes the cosine similarity between the two words
        '''
        try:
            word_one_index = self.word_to_index[word_one]
            word_two_index = self.word_to_index[word_two]
        except KeyError:
            return 0
    
        embedding_one = self.W[word_one_index]
        embedding_two = self.W[word_two_index]
        similarity = 1 - abs(float(cosine(embedding_one, embedding_two)))
        return similarity

# %%
#@jit(nopython=True)
def predict_and_backprop(W, C, learning_rate, center_id, context_id,
                         negative_sample_ids):
    '''
    Using the center token (specified by center_id), makes a forward pass through
    the network to predict the context token (context_id) and negative samples,
    then backprops the error of those predictions to update the network and
    returns the negative log likelihood (Equation 1 in your homework) from the
    current preditions. W and C are the weight matrices of the network and IDs
    refer to particular rows of the matrices (i.e., the word embeddings of the
    target word and the context words!)

    '''

    #
    # GENERAL NOTE: There are many ways to implement this function, depending on
    # how fancy you want to get with numpy. The instructions/steps here are
    # intended as guides for the main tasks on what you have to do and may be
    # implemented as one line or more lines, depending on which methods you use
    # and how you want to write it. The important thing is that it works, not
    # how fast it is, so feel free to write it in a way that is understandable
    # to you. Often when you get to that point, you'll see ways to improve (but
    # first save a copy of your working code!).
    #

    
    # Step 1: Look up the two vectors in W and C. Note that the row for the
    # center_id is effectively the hidden layer activation, h.
    center_vec=W[center_id]
    context_vec=C[context_id]
    # Step 2: Look up the vectors for the negative sample IDs.
    #
    
    
    negative_sample_vecs=C[negative_sample_ids]
    # NOTE: numpy supports multiple indexing (getting multiple rows at once) if
    # you want to use it

    # Step 3: Compute the predictions for the context word and the negative
    # examples. We want the predictions of the context word to be near 1 and
    # those for the negative examples to be near 0.
    context_word_prediction=np.dot(center_vec,context_vec)
    negative_word_prediction=np.matmul(negative_sample_vecs,np.transpose([center_vec]))
    # Step 4: Compute the negative log likelihood
    nll=-np.log(sigmoid(context_word_prediction))-np.sum(np.log(sigmoid(-negative_word_prediction)))
    # Step 5: Update the negative sample vectors to push their dot product with the
    # center word's vecter closer to zero.
    context_vec_new=context_vec-learning_rate*(sigmoid(context_word_prediction)-1)*center_vec
    negative_sample_vecs_new=negative_sample_vecs-np.matmul(learning_rate*(sigmoid(negative_word_prediction)),[center_vec])
    # Step 6: Now backprop all the way back to the center word's vector. Be sure to
    # update it based on the *old* values of the context vectors, not the
    # new values of the context vectors that you just updated!    
    center_vec_new=center_vec-learning_rate*(sigmoid(context_word_prediction)-1)*context_vec
    for i in range(len(negative_word_prediction)):
        center_vec_new=center_vec_new-learning_rate*(sigmoid(negative_word_prediction[i]))*negative_sample_vecs[i]
    #nll = 0
    W[center_id]=center_vec_new
    C[context_id]=context_vec_new
    C[negative_sample_ids]=negative_sample_vecs_new
    return nll
#@jit(nopython=True)
def sigmoid(x):
    '''
    Returns the sigmoid of the provided value
    '''
    return 1.0 / (1 + np.exp(-x))

# %%
with open('synonyms.txt',"r") as f:   
            synonyms= f.read()

# %%
synonyms=synonyms.split('\n')

# %%
for i in range(len(synonyms)):
    synonyms[i]=synonyms[i].split()

# %%
synonyms_key={}
for i in range(len(synonyms)):
    for j in range(len(synonyms[i])):
        synonyms_key[synonyms[i][j]]=i

# %%
all_synonyms_words=list(synonyms_key.keys())

# %%
instance=word2vec()

# %%
instance.load_data('wiki-bios.med.txt',5)
# Out:
# Counting token frequencies
# Performing minimum thresholding
# 23015360
# Loaded all data from wiki-bios.med.txt; saw 18594088 tokens (108206 unique)

# %%
instance.generate_negative_sampling_table()
# Out:
# Generating sampling table
# 108206

# %%
instance.init_weights()

# %%
instance.train()
# Out:
# Beginning epoch 1 of 2
# Negative log-likelihood (step: 10000): 80038.850895
# Negative log-likelihood (step: 20000): 76264.079711
# Negative log-likelihood (step: 30000): 74378.371429
# Negative log-likelihood (step: 40000): 73807.440229
# Negative log-likelihood (step: 50000): 73248.533210
# Negative log-likelihood (step: 60000): 71438.149026
# Negative log-likelihood (step: 70000): 70029.930360
# Negative log-likelihood (step: 80000): 71446.052169
# Negative log-likelihood (step: 90000): 69770.239755
# Negative log-likelihood (step: 100000): 69573.577730
# Negative log-likelihood (step: 110000): 69446.717113
# Negative log-likelihood (step: 120000): 68651.865634
# Negative log-likelihood (step: 130000): 66721.759858
# Negative log-likelihood (step: 140000): 67211.069410
# Negative log-likelihood (step: 150000): 66089.910937
# Negative log-likelihood (step: 160000): 67312.018528
# Negative log-likelihood (step: 170000): 65822.079762
# Negative log-likelihood (step: 180000): 61881.731398
# Negative log-likelihood (step: 190000): 65610.379987
# Negative log-likelihood (step: 200000): 64946.654119
# Negative log-likelihood (step: 210000): 63114.467311
# Negative log-likelihood (step: 220000): 65101.879769
# Negative log-likelihood (step: 230000): 65437.446443
# Negative log-likelihood (step: 240000): 61982.047958
# Negative log-likelihood (step: 250000): 55822.096624
# Negative log-likelihood (step: 260000): 63457.645816
# Negative log-likelihood (step: 270000): 63321.686618
# Negative log-likelihood (step: 280000): 65081.567552
# Negative log-likelihood (step: 290000): 63504.125735
# Negative log-likelihood (step: 300000): 64396.039036
# Negative log-likelihood (step: 310000): 63456.655533
# Negative log-likelihood (step: 320000): 62445.822472
# Negative log-likelihood (step: 330000): 61362.458811
# Negative log-likelihood (step: 340000): 60751.241660
# Negative log-likelihood (step: 350000): 59935.867166
# Negative log-likelihood (step: 360000): 63427.049392
# Negative log-likelihood (step: 370000): 61634.948423
# Negative log-likelihood (step: 380000): 62073.709599
# Negative log-likelihood (step: 390000): 62752.823970
# Negative log-likelihood (step: 400000): 62697.413238
# Negative log-likelihood (step: 410000): 62177.211939
# Negative log-likelihood (step: 420000): 59302.879406
# Negative log-likelihood (step: 430000): 61002.570255
# Negative log-likelihood (step: 440000): 58003.873021
# Negative log-likelihood (step: 450000): 62501.580748
# Negative log-likelihood (step: 460000): 62015.576112
# Negative log-likelihood (step: 470000): 55080.304435
# Negative log-likelihood (step: 480000): 62872.596944
# Negative log-likelihood (step: 490000): 60315.376478
# Negative log-likelihood (step: 500000): 60899.539774
# Negative log-likelihood (step: 510000): 60247.955454
# Negative log-likelihood (step: 520000): 60788.666948
# Negative log-likelihood (step: 530000): 60574.701367
# Negative log-likelihood (step: 540000): 60463.650898
# Negative log-likelihood (step: 550000): 59668.800417
# Negative log-likelihood (step: 560000): 59512.579745
# Negative log-likelihood (step: 570000): 59772.180096
# Negative log-likelihood (step: 580000): 61245.302698
# Negative log-likelihood (step: 590000): 61439.920628
# Negative log-likelihood (step: 600000): 60053.937099
# Negative log-likelihood (step: 610000): 60275.194171
# Negative log-likelihood (step: 620000): 59237.813593
# Negative log-likelihood (step: 630000): 58028.694537
# Negative log-likelihood (step: 640000): 59537.350954
# Negative log-likelihood (step: 650000): 60031.936823
# Negative log-likelihood (step: 660000): 60277.403777
# Negative log-likelihood (step: 670000): 61025.033977
# Negative log-likelihood (step: 680000): 57712.626156
# Negative log-likelihood (step: 690000): 59452.232886
# Negative log-likelihood (step: 700000): 58478.810608
# Negative log-likelihood (step: 710000): 59109.684710
# Negative log-likelihood (step: 720000): 60128.771068
# Negative log-likelihood (step: 730000): 57720.736513
# Negative log-likelihood (step: 740000): 58238.711499
# Negative log-likelihood (step: 750000): 60564.820129
# Negative log-likelihood (step: 760000): 58196.961559
# Negative log-likelihood (step: 770000): 58875.799989
# Negative log-likelihood (step: 780000): 59076.210555
# Negative log-likelihood (step: 790000): 57824.980863
# Negative log-likelihood (step: 800000): 56726.487042
# Negative log-likelihood (step: 810000): 59662.049653
# Negative log-likelihood (step: 820000): 57342.963514
# Negative log-likelihood (step: 830000): 58113.371034
# Negative log-likelihood (step: 840000): 53004.075641
# Negative log-likelihood (step: 850000): 57625.092827
# Negative log-likelihood (step: 860000): 58174.315542
# Negative log-likelihood (step: 870000): 58510.887941
# Negative log-likelihood (step: 880000): 56569.636429
# Negative log-likelihood (step: 890000): 57226.202220
# Negative log-likelihood (step: 900000): 59734.310891
# Negative log-likelihood (step: 910000): 58230.801458
# Negative log-likelihood (step: 920000): 58121.899688
# Negative log-likelihood (step: 930000): 55300.521552
# Negative log-likelihood (step: 940000): 53589.237209
# Negative log-likelihood (step: 950000): 59194.843475
# Negative log-likelihood (step: 960000): 56969.533269
# Negative log-likelihood (step: 970000): 59068.629927
# Negative log-likelihood (step: 980000): 57839.986302
# Negative log-likelihood (step: 990000): 59355.719062
# Negative log-likelihood (step: 1000000): 58441.187331
# Negative log-likelihood (step: 1010000): 58331.259424
# Negative log-likelihood (step: 1020000): 55660.115911
# Negative log-likelihood (step: 1030000): 59555.935255
# Negative log-likelihood (step: 1040000): 57313.179908
# Negative log-likelihood (step: 1050000): 57618.253932
# Negative log-likelihood (step: 1060000): 56395.778653
# Negative log-likelihood (step: 1070000): 58180.766354
# Negative log-likelihood (step: 1080000): 57343.816877
# Negative log-likelihood (step: 1090000): 55590.672929
# Negative log-likelihood (step: 1100000): 54304.716183
# Negative log-likelihood (step: 1110000): 58438.559474
# Negative log-likelihood (step: 1120000): 57451.499846
# Negative log-likelihood (step: 1130000): 58512.625076
# Negative log-likelihood (step: 1140000): 59160.391362
# Negative log-likelihood (step: 1150000): 58086.939985
# Negative log-likelihood (step: 1160000): 57824.513055
# Negative log-likelihood (step: 1170000): 57215.961758
# Negative log-likelihood (step: 1180000): 54758.119484
# Negative log-likelihood (step: 1190000): 57547.847909
# Negative log-likelihood (step: 1200000): 57598.648737
# Negative log-likelihood (step: 1210000): 59712.902940
# Negative log-likelihood (step: 1220000): 57115.046962
# Negative log-likelihood (step: 1230000): 58102.398099
# Negative log-likelihood (step: 1240000): 57862.710894
# Negative log-likelihood (step: 1250000): 56376.862412
# Negative log-likelihood (step: 1260000): 55610.217437
# Negative log-likelihood (step: 1270000): 56703.761659
# Negative log-likelihood (step: 1280000): 56871.172508
# Negative log-likelihood (step: 1290000): 58166.955175
# Negative log-likelihood (step: 1300000): 57923.862383
# Negative log-likelihood (step: 1310000): 58734.001211
# Negative log-likelihood (step: 1320000): 57915.471107
# Negative log-likelihood (step: 1330000): 56695.375875
# Negative log-likelihood (step: 1340000): 55682.212319
# Negative log-likelihood (step: 1350000): 56701.865919
# Negative log-likelihood (step: 1360000): 56703.587289
# Negative log-likelihood (step: 1370000): 53533.519736
# Negative log-likelihood (step: 1380000): 57344.899257
# Negative log-likelihood (step: 1390000): 57609.798788
# Negative log-likelihood (step: 1400000): 56317.768526
# Negative log-likelihood (step: 1410000): 56952.587759
# Negative log-likelihood (step: 1420000): 55256.727211
# Negative log-likelihood (step: 1430000): 56770.766648
# Negative log-likelihood (step: 1440000): 57112.344035
# Negative log-likelihood (step: 1450000): 57653.602868
# Negative log-likelihood (step: 1460000): 56291.925828
# Negative log-likelihood (step: 1470000): 54583.905120
# Negative log-likelihood (step: 1480000): 55257.722472
# Negative log-likelihood (step: 1490000): 58226.848803
# Negative log-likelihood (step: 1500000): 57507.953728
# Negative log-likelihood (step: 1510000): 57116.198381
# Negative log-likelihood (step: 1520000): 58189.291151
# Negative log-likelihood (step: 1530000): 57725.594747
# Negative log-likelihood (step: 1540000): 54444.014629
# Negative log-likelihood (step: 1550000): 54775.299384
# Negative log-likelihood (step: 1560000): 56075.113171
# Negative log-likelihood (step: 1570000): 58203.412569
# Negative log-likelihood (step: 1580000): 53277.816424
# Negative log-likelihood (step: 1590000): 58231.320216
# Negative log-likelihood (step: 1600000): 58236.777404
# Negative log-likelihood (step: 1610000): 57568.770114
# Negative log-likelihood (step: 1620000): 55781.587761
# Negative log-likelihood (step: 1630000): 55009.520753
# Negative log-likelihood (step: 1640000): 58044.596920
# Negative log-likelihood (step: 1650000): 56629.563086
# Negative log-likelihood (step: 1660000): 55164.840159
# Negative log-likelihood (step: 1670000): 58597.953031
# Negative log-likelihood (step: 1680000): 57436.342280
# Negative log-likelihood (step: 1690000): 57161.544507
# Negative log-likelihood (step: 1700000): 56248.252447
# Negative log-likelihood (step: 1710000): 55869.352074
# Negative log-likelihood (step: 1720000): 58497.308853
# Negative log-likelihood (step: 1730000): 57657.378127
# Negative log-likelihood (step: 1740000): 57119.930881
# Negative log-likelihood (step: 1750000): 57973.035275
# Negative log-likelihood (step: 1760000): 57931.492528
# Negative log-likelihood (step: 1770000): 56469.391980
# Negative log-likelihood (step: 1780000): 55653.862480
# Negative log-likelihood (step: 1790000): 56608.913517
# Negative log-likelihood (step: 1800000): 57263.154106
# Negative log-likelihood (step: 1810000): 55672.658950
# Negative log-likelihood (step: 1820000): 57078.204644
# Negative log-likelihood (step: 1830000): 56878.163421
# Negative log-likelihood (step: 1840000): 54768.641970
# Negative log-likelihood (step: 1850000): 57853.319010
# Negative log-likelihood (step: 1860000): 56383.229787
# Negative log-likelihood (step: 1870000): 57198.750133
# Negative log-likelihood (step: 1880000): 57063.283310
# Negative log-likelihood (step: 1890000): 55734.414883
# Negative log-likelihood (step: 1900000): 53866.653806
# Negative log-likelihood (step: 1910000): 55962.818481
# Negative log-likelihood (step: 1920000): 56640.896764
# Negative log-likelihood (step: 1930000): 53941.255671
# Negative log-likelihood (step: 1940000): 56954.863758
# Negative log-likelihood (step: 1950000): 56733.777696
# Negative log-likelihood (step: 1960000): 55231.009957
# Negative log-likelihood (step: 1970000): 58492.439804
# Negative log-likelihood (step: 1980000): 57575.825342
# Negative log-likelihood (step: 1990000): 58444.316217
# Negative log-likelihood (step: 2000000): 58438.803462
# Negative log-likelihood (step: 2010000): 55348.846997
# Negative log-likelihood (step: 2020000): 56134.379754
# Negative log-likelihood (step: 2030000): 55478.445802
# Negative log-likelihood (step: 2040000): 57940.807338
# Negative log-likelihood (step: 2050000): 56919.495650
# Negative log-likelihood (step: 2060000): 56818.118659
# Negative log-likelihood (step: 2070000): 56940.647964
# Negative log-likelihood (step: 2080000): 54457.185626
# Negative log-likelihood (step: 2090000): 56098.867550
# Negative log-likelihood (step: 2100000): 55737.900005
# Negative log-likelihood (step: 2110000): 55139.599127
# Negative log-likelihood (step: 2120000): 56158.867480
# Negative log-likelihood (step: 2130000): 57420.360495
# Negative log-likelihood (step: 2140000): 56844.051003
# Negative log-likelihood (step: 2150000): 56324.412214
# Negative log-likelihood (step: 2160000): 57668.066705
# Negative log-likelihood (step: 2170000): 56398.170922
# Negative log-likelihood (step: 2180000): 58058.116353
# Negative log-likelihood (step: 2190000): 56702.967745
# Negative log-likelihood (step: 2200000): 55258.142451
# Negative log-likelihood (step: 2210000): 56824.404855
# Negative log-likelihood (step: 2220000): 57101.512744
# Negative log-likelihood (step: 2230000): 56298.769146
# Negative log-likelihood (step: 2240000): 58270.384738
# Negative log-likelihood (step: 2250000): 56694.058267
# Negative log-likelihood (step: 2260000): 58075.861358
# Negative log-likelihood (step: 2270000): 56569.129673
# Negative log-likelihood (step: 2280000): 54019.003404
# Negative log-likelihood (step: 2290000): 56511.042869
# Negative log-likelihood (step: 2300000): 56805.373440
# Negative log-likelihood (step: 2310000): 58013.289185
# Negative log-likelihood (step: 2320000): 56646.300880
# Negative log-likelihood (step: 2330000): 55309.828086
# Negative log-likelihood (step: 2340000): 55237.246017
# Negative log-likelihood (step: 2350000): 49884.316510
# Negative log-likelihood (step: 2360000): 55557.364207
# Negative log-likelihood (step: 2370000): 58399.163803
# Negative log-likelihood (step: 2380000): 56159.388386
# Negative log-likelihood (step: 2390000): 56391.025483
# Negative log-likelihood (step: 2400000): 56558.326861
# Negative log-likelihood (step: 2410000): 58492.980208
# Negative log-likelihood (step: 2420000): 54873.967554
# Negative log-likelihood (step: 2430000): 57755.016497
# Negative log-likelihood (step: 2440000): 54137.841221
# Negative log-likelihood (step: 2450000): 55996.513079
# Negative log-likelihood (step: 2460000): 55507.986132
# Negative log-likelihood (step: 2470000): 57517.101132
# Negative log-likelihood (step: 2480000): 55024.083716
# Negative log-likelihood (step: 2490000): 54475.715730
# Negative log-likelihood (step: 2500000): 55417.603938
# Negative log-likelihood (step: 2510000): 58501.416565
# Negative log-likelihood (step: 2520000): 52736.836856
# Negative log-likelihood (step: 2530000): 55744.867806
# Negative log-likelihood (step: 2540000): 55671.754768
# Negative log-likelihood (step: 2550000): 57372.229250
# Negative log-likelihood (step: 2560000): 54359.514201
# Negative log-likelihood (step: 2570000): 56132.876719
# Negative log-likelihood (step: 2580000): 57198.153033
# Negative log-likelihood (step: 2590000): 53951.101644
# Negative log-likelihood (step: 2600000): 55102.257338
# Negative log-likelihood (step: 2610000): 56633.692743
# Negative log-likelihood (step: 2620000): 56544.313188
# Negative log-likelihood (step: 2630000): 57264.274475
# Negative log-likelihood (step: 2640000): 55423.157439
# Negative log-likelihood (step: 2650000): 55229.690595
# Negative log-likelihood (step: 2660000): 55128.476156
# Negative log-likelihood (step: 2670000): 56863.008213
# Negative log-likelihood (step: 2680000): 56809.274687
# Negative log-likelihood (step: 2690000): 56592.685936
# Negative log-likelihood (step: 2700000): 57378.396881
# Negative log-likelihood (step: 2710000): 57081.095548
# Negative log-likelihood (step: 2720000): 55620.678698
# Negative log-likelihood (step: 2730000): 55097.317632
# Negative log-likelihood (step: 2740000): 55107.344771
# Negative log-likelihood (step: 2750000): 55534.632226
# Negative log-likelihood (step: 2760000): 55810.302980
# Negative log-likelihood (step: 2770000): 55411.853650
# Negative log-likelihood (step: 2780000): 57373.896994
# Negative log-likelihood (step: 2790000): 56543.311724
# Negative log-likelihood (step: 2800000): 52916.832499
# Negative log-likelihood (step: 2810000): 56873.033469
# Negative log-likelihood (step: 2820000): 55251.184318
# Negative log-likelihood (step: 2830000): 55393.525926
# Negative log-likelihood (step: 2840000): 56005.884114
# Negative log-likelihood (step: 2850000): 57099.618357
# Negative log-likelihood (step: 2860000): 56854.150179
# Negative log-likelihood (step: 2870000): 57792.924077
# Negative log-likelihood (step: 2880000): 55612.501090
# Negative log-likelihood (step: 2890000): 52754.083874
# Negative log-likelihood (step: 2900000): 53282.649052
# Negative log-likelihood (step: 2910000): 55144.322197
# Negative log-likelihood (step: 2920000): 57541.285168
# Negative log-likelihood (step: 2930000): 56284.364035
# Negative log-likelihood (step: 2940000): 57035.651260
# Negative log-likelihood (step: 2950000): 53262.759814
# Negative log-likelihood (step: 2960000): 56788.524406
# Negative log-likelihood (step: 2970000): 56943.187606
# Negative log-likelihood (step: 2980000): 55853.683652
# Negative log-likelihood (step: 2990000): 56961.579418
# Negative log-likelihood (step: 3000000): 57838.585411
# Negative log-likelihood (step: 3010000): 54990.342937
# Negative log-likelihood (step: 3020000): 51554.630139
# Negative log-likelihood (step: 3030000): 58107.521124
# Negative log-likelihood (step: 3040000): 56623.790422
# Negative log-likelihood (step: 3050000): 54377.418674
# Negative log-likelihood (step: 3060000): 58037.040375
# Negative log-likelihood (step: 3070000): 56024.048400
# Negative log-likelihood (step: 3080000): 52955.355568
# Negative log-likelihood (step: 3090000): 56103.546879
# Negative log-likelihood (step: 3100000): 56946.889492
# Negative log-likelihood (step: 3110000): 56614.470034
# Negative log-likelihood (step: 3120000): 54181.859953
# Negative log-likelihood (step: 3130000): 56699.561874
# Negative log-likelihood (step: 3140000): 55183.680562
# Negative log-likelihood (step: 3150000): 57369.094946
# Negative log-likelihood (step: 3160000): 56609.929937
# Negative log-likelihood (step: 3170000): 53430.091167
# Negative log-likelihood (step: 3180000): 56860.716208
# Negative log-likelihood (step: 3190000): 58463.351529
# Negative log-likelihood (step: 3200000): 55293.696669
# Negative log-likelihood (step: 3210000): 55110.229593
# Negative log-likelihood (step: 3220000): 56156.194470
# Negative log-likelihood (step: 3230000): 56538.830849
# Negative log-likelihood (step: 3240000): 56996.154850
# Negative log-likelihood (step: 3250000): 57350.666745
# Negative log-likelihood (step: 3260000): 57281.811722
# Negative log-likelihood (step: 3270000): 57931.400363
# Negative log-likelihood (step: 3280000): 56290.699275
# Negative log-likelihood (step: 3290000): 56478.400343
# Negative log-likelihood (step: 3300000): 57347.721230
# Negative log-likelihood (step: 3310000): 56595.417388
# Negative log-likelihood (step: 3320000): 56049.454091
# Negative log-likelihood (step: 3330000): 56844.306885
# Negative log-likelihood (step: 3340000): 55791.788125
# Negative log-likelihood (step: 3350000): 56663.361129
# Negative log-likelihood (step: 3360000): 56748.337315
# Negative log-likelihood (step: 3370000): 54753.276683
# Negative log-likelihood (step: 3380000): 56030.813920
# Negative log-likelihood (step: 3390000): 55947.043758
# Negative log-likelihood (step: 3400000): 56625.906751
# Negative log-likelihood (step: 3410000): 55084.133358
# Negative log-likelihood (step: 3420000): 56254.314254
# Negative log-likelihood (step: 3430000): 56777.410631
# Negative log-likelihood (step: 3440000): 56239.014789
# Negative log-likelihood (step: 3450000): 55721.131169
# Negative log-likelihood (step: 3460000): 56628.787450
# Negative log-likelihood (step: 3470000): 55725.568627
# Negative log-likelihood (step: 3480000): 56933.909867
# Negative log-likelihood (step: 3490000): 55575.162511
# Negative log-likelihood (step: 3500000): 57813.920334
# Negative log-likelihood (step: 3510000): 55430.809514
# Negative log-likelihood (step: 3520000): 57141.138480
# Negative log-likelihood (step: 3530000): 55909.213258
# Negative log-likelihood (step: 3540000): 57862.289098
# Negative log-likelihood (step: 3550000): 51463.605354
# Negative log-likelihood (step: 3560000): 52185.007539
# Negative log-likelihood (step: 3570000): 54610.044517
# Negative log-likelihood (step: 3580000): 55845.551466
# Negative log-likelihood (step: 3590000): 56868.140807
# Negative log-likelihood (step: 3600000): 57275.383380
# Negative log-likelihood (step: 3610000): 56243.081975
# Negative log-likelihood (step: 3620000): 56553.342189
# Negative log-likelihood (step: 3630000): 55943.211096
# Negative log-likelihood (step: 3640000): 56988.899029
# Negative log-likelihood (step: 3650000): 55643.274872
# Negative log-likelihood (step: 3660000): 56094.103443
# Negative log-likelihood (step: 3670000): 56748.916666
# Negative log-likelihood (step: 3680000): 54724.691776
# Negative log-likelihood (step: 3690000): 57611.344744
# Negative log-likelihood (step: 3700000): 56436.040405
# Negative log-likelihood (step: 3710000): 56806.482753
# Negative log-likelihood (step: 3720000): 55527.783848
# Negative log-likelihood (step: 3730000): 53404.692263
# Negative log-likelihood (step: 3740000): 55501.530113
# Negative log-likelihood (step: 3750000): 56526.970011
# Negative log-likelihood (step: 3760000): 56315.081328
# Negative log-likelihood (step: 3770000): 57723.341270
# Negative log-likelihood (step: 3780000): 53113.215353
# Negative log-likelihood (step: 3790000): 53314.467189
# Negative log-likelihood (step: 3800000): 57387.782891
# Negative log-likelihood (step: 3810000): 56434.527385
# Negative log-likelihood (step: 3820000): 53506.308148
# Negative log-likelihood (step: 3830000): 55625.051861
# Negative log-likelihood (step: 3840000): 55324.616611
# Negative log-likelihood (step: 3850000): 57549.600558
# Negative log-likelihood (step: 3860000): 56722.388888
# Negative log-likelihood (step: 3870000): 57133.455321
# Negative log-likelihood (step: 3880000): 57316.495663
# Negative log-likelihood (step: 3890000): 56848.546112
# Negative log-likelihood (step: 3900000): 56935.481421
# Negative log-likelihood (step: 3910000): 52828.027885
# Negative log-likelihood (step: 3920000): 50691.092115
# Negative log-likelihood (step: 3930000): 54520.340857
# Negative log-likelihood (step: 3940000): 54384.870778
# Negative log-likelihood (step: 3950000): 55723.425291
# Negative log-likelihood (step: 3960000): 54976.915972
# Negative log-likelihood (step: 3970000): 53259.399058
# Negative log-likelihood (step: 3980000): 54772.878715
# Negative log-likelihood (step: 3990000): 56283.617002
# Negative log-likelihood (step: 4000000): 54410.990578
# Negative log-likelihood (step: 4010000): 55816.573860
# Negative log-likelihood (step: 4020000): 56618.412961
# Negative log-likelihood (step: 4030000): 55624.855191
# Negative log-likelihood (step: 4040000): 57105.543082
# Negative log-likelihood (step: 4050000): 56682.995328
# Negative log-likelihood (step: 4060000): 57049.822125
# Negative log-likelihood (step: 4070000): 56819.178763
# Negative log-likelihood (step: 4080000): 55144.233957
# Negative log-likelihood (step: 4090000): 55722.863817
# Negative log-likelihood (step: 4100000): 57185.601139
# Negative log-likelihood (step: 4110000): 52360.800061
# Negative log-likelihood (step: 4120000): 55268.298718
# Negative log-likelihood (step: 4130000): 56075.351743
# Negative log-likelihood (step: 4140000): 56996.719155
# Negative log-likelihood (step: 4150000): 57073.355889
# Negative log-likelihood (step: 4160000): 54809.613917
# Negative log-likelihood (step: 4170000): 54798.394704
# Negative log-likelihood (step: 4180000): 57187.583110
# Negative log-likelihood (step: 4190000): 54421.454994
# Negative log-likelihood (step: 4200000): 55973.204071
# Negative log-likelihood (step: 4210000): 54860.891355
# Negative log-likelihood (step: 4220000): 54816.586721
# Negative log-likelihood (step: 4230000): 56189.188783
# Negative log-likelihood (step: 4240000): 56483.277280
# Negative log-likelihood (step: 4250000): 56086.980004
# Negative log-likelihood (step: 4260000): 55056.266187
# Negative log-likelihood (step: 4270000): 55618.334035
# Negative log-likelihood (step: 4280000): 56432.367276
# Negative log-likelihood (step: 4290000): 56538.225954
# Negative log-likelihood (step: 4300000): 54990.498993
# Negative log-likelihood (step: 4310000): 57412.601039
# Negative log-likelihood (step: 4320000): 55752.785216
# Negative log-likelihood (step: 4330000): 56212.432919
# Negative log-likelihood (step: 4340000): 57647.178351
# Negative log-likelihood (step: 4350000): 57231.133056
# Negative log-likelihood (step: 4360000): 56682.760072
# Negative log-likelihood (step: 4370000): 55623.864049
# Negative log-likelihood (step: 4380000): 55004.912984
# Negative log-likelihood (step: 4390000): 54787.849383
# Negative log-likelihood (step: 4400000): 57965.561819
# Negative log-likelihood (step: 4410000): 56088.323617
# Negative log-likelihood (step: 4420000): 56960.565265
# Negative log-likelihood (step: 4430000): 55257.204554
# Negative log-likelihood (step: 4440000): 57180.998285
# Negative log-likelihood (step: 4450000): 56619.294283
# Negative log-likelihood (step: 4460000): 56924.394762
# Negative log-likelihood (step: 4470000): 57010.819049
# Negative log-likelihood (step: 4480000): 54771.395374
# Negative log-likelihood (step: 4490000): 55559.279226
# Negative log-likelihood (step: 4500000): 56458.680068
# Negative log-likelihood (step: 4510000): 56308.159539
# Negative log-likelihood (step: 4520000): 57238.399989
# Negative log-likelihood (step: 4530000): 55015.149921
# Negative log-likelihood (step: 4540000): 53515.979131
# Negative log-likelihood (step: 4550000): 54952.653069
# Negative log-likelihood (step: 4560000): 55591.317924
# Negative log-likelihood (step: 4570000): 56158.423374
# Negative log-likelihood (step: 4580000): 55906.038763
# Negative log-likelihood (step: 4590000): 55921.504809
# Negative log-likelihood (step: 4600000): 53901.946146
# Negative log-likelihood (step: 4610000): 53631.350115
# Negative log-likelihood (step: 4620000): 56680.475903
# Negative log-likelihood (step: 4630000): 54989.759180
# Negative log-likelihood (step: 4640000): 55734.671156
# Negative log-likelihood (step: 4650000): 56859.333902
# Negative log-likelihood (step: 4660000): 54402.950893
# Negative log-likelihood (step: 4670000): 54149.927536
# Negative log-likelihood (step: 4680000): 55842.365313
# Negative log-likelihood (step: 4690000): 54863.476678
# Negative log-likelihood (step: 4700000): 57527.115981
# Negative log-likelihood (step: 4710000): 55728.710333
# Negative log-likelihood (step: 4720000): 56683.788869
# Negative log-likelihood (step: 4730000): 55581.851336
# Negative log-likelihood (step: 4740000): 55849.216297
# Negative log-likelihood (step: 4750000): 57460.437569
# Negative log-likelihood (step: 4760000): 56692.801459
# Negative log-likelihood (step: 4770000): 55799.424404
# Negative log-likelihood (step: 4780000): 51810.758164
# Negative log-likelihood (step: 4790000): 56612.955383
# Negative log-likelihood (step: 4800000): 55844.148469
# Negative log-likelihood (step: 4810000): 57035.911929
# Negative log-likelihood (step: 4820000): 57224.940224
# Negative log-likelihood (step: 4830000): 56155.496619
# Negative log-likelihood (step: 4840000): 56183.772681
# Negative log-likelihood (step: 4850000): 55560.027912
# Negative log-likelihood (step: 4860000): 56770.824893
# Negative log-likelihood (step: 4870000): 57312.332867
# Negative log-likelihood (step: 4880000): 56969.085885
# Negative log-likelihood (step: 4890000): 54911.106323
# Negative log-likelihood (step: 4900000): 56151.686176
# Negative log-likelihood (step: 4910000): 57540.538939
# Negative log-likelihood (step: 4920000): 57064.277958
# Negative log-likelihood (step: 4930000): 56121.992430
# Negative log-likelihood (step: 4940000): 56810.503536
# Negative log-likelihood (step: 4950000): 55184.240933
# Negative log-likelihood (step: 4960000): 57223.789697
# Negative log-likelihood (step: 4970000): 56079.038226
# Negative log-likelihood (step: 4980000): 54966.709534
# Negative log-likelihood (step: 4990000): 57033.162596
# Negative log-likelihood (step: 5000000): 57983.154545
# Negative log-likelihood (step: 5010000): 57103.641818
# Negative log-likelihood (step: 5020000): 55435.252430
# Negative log-likelihood (step: 5030000): 54435.086201
# Negative log-likelihood (step: 5040000): 56766.069522
# Negative log-likelihood (step: 5050000): 56599.214573
# Negative log-likelihood (step: 5060000): 56927.693825
# Negative log-likelihood (step: 5070000): 56410.648954
# Negative log-likelihood (step: 5080000): 56039.900513
# Negative log-likelihood (step: 5090000): 54067.230735
# Negative log-likelihood (step: 5100000): 54992.248054
# Negative log-likelihood (step: 5110000): 55603.142869
# Negative log-likelihood (step: 5120000): 55337.234325
# Negative log-likelihood (step: 5130000): 57297.614985
# Negative log-likelihood (step: 5140000): 55870.727096
# Negative log-likelihood (step: 5150000): 55180.298272
# Negative log-likelihood (step: 5160000): 56404.681733
# Negative log-likelihood (step: 5170000): 56265.104797
# Negative log-likelihood (step: 5180000): 57020.557208
# Negative log-likelihood (step: 5190000): 56355.519785
# Negative log-likelihood (step: 5200000): 56683.308291
# Negative log-likelihood (step: 5210000): 55819.648717
# Negative log-likelihood (step: 5220000): 54480.323941
# Negative log-likelihood (step: 5230000): 57758.290001
# Negative log-likelihood (step: 5240000): 54484.539212
# Negative log-likelihood (step: 5250000): 53496.658925
# Negative log-likelihood (step: 5260000): 54119.398496
# Negative log-likelihood (step: 5270000): 55707.920647
# Negative log-likelihood (step: 5280000): 57532.279106
# Negative log-likelihood (step: 5290000): 54994.226661
# Negative log-likelihood (step: 5300000): 53673.945578
# Negative log-likelihood (step: 5310000): 55983.349834
# Negative log-likelihood (step: 5320000): 56758.885059
# Negative log-likelihood (step: 5330000): 57159.006078
# Negative log-likelihood (step: 5340000): 57326.998895
# Negative log-likelihood (step: 5350000): 55820.031226
# Negative log-likelihood (step: 5360000): 54447.151412
# Negative log-likelihood (step: 5370000): 56380.762959
# Negative log-likelihood (step: 5380000): 56545.605574
# Negative log-likelihood (step: 5390000): 56211.871841
# Negative log-likelihood (step: 5400000): 55692.203155
# Negative log-likelihood (step: 5410000): 54745.684295
# Negative log-likelihood (step: 5420000): 57067.388772
# Negative log-likelihood (step: 5430000): 56584.552279
# Negative log-likelihood (step: 5440000): 52943.550172
# Negative log-likelihood (step: 5450000): 54693.803724
# Negative log-likelihood (step: 5460000): 56761.442077
# Negative log-likelihood (step: 5470000): 55693.089293
# Negative log-likelihood (step: 5480000): 54300.434277
# Negative log-likelihood (step: 5490000): 52762.126168
# Negative log-likelihood (step: 5500000): 54420.525467
# Negative log-likelihood (step: 5510000): 51939.775876
# Negative log-likelihood (step: 5520000): 56019.934975
# Negative log-likelihood (step: 5530000): 55756.898925
# Negative log-likelihood (step: 5540000): 55055.162829
# Negative log-likelihood (step: 5550000): 55906.859878
# Negative log-likelihood (step: 5560000): 52986.410382
# Negative log-likelihood (step: 5570000): 56215.758512
# Negative log-likelihood (step: 5580000): 57193.099191
# Negative log-likelihood (step: 5590000): 55677.506390
# Negative log-likelihood (step: 5600000): 56844.464660
# Negative log-likelihood (step: 5610000): 53942.032693
# Negative log-likelihood (step: 5620000): 54478.634447
# Negative log-likelihood (step: 5630000): 54819.280900
# Negative log-likelihood (step: 5640000): 56425.228195
# Negative log-likelihood (step: 5650000): 54794.730343
# Negative log-likelihood (step: 5660000): 55825.641023
# Negative log-likelihood (step: 5670000): 55461.366007
# Negative log-likelihood (step: 5680000): 56208.405767
# Negative log-likelihood (step: 5690000): 53823.845691
# Negative log-likelihood (step: 5700000): 55648.989509
# Negative log-likelihood (step: 5710000): 54015.567322
# Negative log-likelihood (step: 5720000): 56759.461432
# Negative log-likelihood (step: 5730000): 55790.935740
# Negative log-likelihood (step: 5740000): 56251.303741
# Negative log-likelihood (step: 5750000): 55778.220266
# Negative log-likelihood (step: 5760000): 56354.094685
# Negative log-likelihood (step: 5770000): 53576.348470
# Negative log-likelihood (step: 5780000): 57289.079936
# Negative log-likelihood (step: 5790000): 53741.197784
# Negative log-likelihood (step: 5800000): 55958.786501
# Negative log-likelihood (step: 5810000): 53914.326773
# Negative log-likelihood (step: 5820000): 54019.544806
# Negative log-likelihood (step: 5830000): 55657.056849
# Negative log-likelihood (step: 5840000): 55641.093390
# Negative log-likelihood (step: 5850000): 56287.886330
# Negative log-likelihood (step: 5860000): 53974.783978
# Negative log-likelihood (step: 5870000): 56069.090754
# Negative log-likelihood (step: 5880000): 54991.932651
# Negative log-likelihood (step: 5890000): 57212.509005
# Negative log-likelihood (step: 5900000): 55677.655713
# Negative log-likelihood (step: 5910000): 55260.949909
# Negative log-likelihood (step: 5920000): 55019.030561
# Negative log-likelihood (step: 5930000): 56873.352587
# Negative log-likelihood (step: 5940000): 56673.600315
# Negative log-likelihood (step: 5950000): 57317.873229
# Negative log-likelihood (step: 5960000): 55610.920412
# Negative log-likelihood (step: 5970000): 56932.521547
# Negative log-likelihood (step: 5980000): 54547.102067
# Negative log-likelihood (step: 5990000): 55877.351841
# Negative log-likelihood (step: 6000000): 54892.475285
# Negative log-likelihood (step: 6010000): 49392.883623
# Negative log-likelihood (step: 6020000): 55964.056362
# Negative log-likelihood (step: 6030000): 57242.165386
# Negative log-likelihood (step: 6040000): 54458.560304
# Negative log-likelihood (step: 6050000): 51593.978797
# Negative log-likelihood (step: 6060000): 55816.413765
# Negative log-likelihood (step: 6070000): 56735.659137
# Negative log-likelihood (step: 6080000): 57531.041450
# Negative log-likelihood (step: 6090000): 54203.973896
# Negative log-likelihood (step: 6100000): 56105.234188
# Negative log-likelihood (step: 6110000): 54839.815188
# Negative log-likelihood (step: 6120000): 54200.651830
# Negative log-likelihood (step: 6130000): 54557.764827
# Negative log-likelihood (step: 6140000): 43094.666204
# Negative log-likelihood (step: 6150000): 57177.741863
# Negative log-likelihood (step: 6160000): 56479.147071
# Negative log-likelihood (step: 6170000): 55415.432684
# Negative log-likelihood (step: 6180000): 57463.855922
# Negative log-likelihood (step: 6190000): 56612.291248
# Negative log-likelihood (step: 6200000): 54870.764888
# Negative log-likelihood (step: 6210000): 56800.070218
# Negative log-likelihood (step: 6220000): 57621.627536
# Negative log-likelihood (step: 6230000): 56027.130783
# Negative log-likelihood (step: 6240000): 56593.967198
# Negative log-likelihood (step: 6250000): 54740.788926
# Negative log-likelihood (step: 6260000): 55982.440524
# Negative log-likelihood (step: 6270000): 56528.152981
# Negative log-likelihood (step: 6280000): 56362.813775
# Negative log-likelihood (step: 6290000): 56080.729306
# Negative log-likelihood (step: 6300000): 57589.764148
# Negative log-likelihood (step: 6310000): 55326.033088
# Negative log-likelihood (step: 6320000): 55061.047612
# Negative log-likelihood (step: 6330000): 56857.571953
# Negative log-likelihood (step: 6340000): 52094.475955
# Negative log-likelihood (step: 6350000): 48468.260992
# Negative log-likelihood (step: 6360000): 57544.590324
# Negative log-likelihood (step: 6370000): 57573.191097
# Negative log-likelihood (step: 6380000): 54245.052188
# Negative log-likelihood (step: 6390000): 57047.537002
# Negative log-likelihood (step: 6400000): 56378.121028
# Negative log-likelihood (step: 6410000): 56717.616928
# Negative log-likelihood (step: 6420000): 56473.532654
# Negative log-likelihood (step: 6430000): 53820.470627
# Negative log-likelihood (step: 6440000): 54289.588968
# Negative log-likelihood (step: 6450000): 56573.840034
# Negative log-likelihood (step: 6460000): 56169.072349
# Negative log-likelihood (step: 6470000): 40725.700624
# Negative log-likelihood (step: 6480000): 55692.431011
# Negative log-likelihood (step: 6490000): 53676.509700
# Negative log-likelihood (step: 6500000): 55115.970530
# Negative log-likelihood (step: 6510000): 53722.839137
# Negative log-likelihood (step: 6520000): 51853.703044
# Negative log-likelihood (step: 6530000): 56932.437865
# Negative log-likelihood (step: 6540000): 56208.533046
# Negative log-likelihood (step: 6550000): 56386.497450
# Negative log-likelihood (step: 6560000): 55517.800923
# Negative log-likelihood (step: 6570000): 56677.389744
# Negative log-likelihood (step: 6580000): 56529.035041
# Negative log-likelihood (step: 6590000): 57416.472904
# Negative log-likelihood (step: 6600000): 57557.467436
# Negative log-likelihood (step: 6610000): 55162.046713
# Negative log-likelihood (step: 6620000): 55095.579092
# Negative log-likelihood (step: 6630000): 56377.769352
# Negative log-likelihood (step: 6640000): 56574.689773
# Negative log-likelihood (step: 6650000): 54410.544579
# Negative log-likelihood (step: 6660000): 56941.993583
# Negative log-likelihood (step: 6670000): 54525.484946
# Negative log-likelihood (step: 6680000): 54403.201651
# Negative log-likelihood (step: 6690000): 56472.964411
# Negative log-likelihood (step: 6700000): 55923.714982
# Negative log-likelihood (step: 6710000): 54920.904391
# Negative log-likelihood (step: 6720000): 54634.912720
# Negative log-likelihood (step: 6730000): 56615.106408
# Negative log-likelihood (step: 6740000): 56548.919046
# Negative log-likelihood (step: 6750000): 54663.016640
# Negative log-likelihood (step: 6760000): 55939.626995
# Negative log-likelihood (step: 6770000): 56477.187909
# Negative log-likelihood (step: 6780000): 55482.130392
# Negative log-likelihood (step: 6790000): 54731.851973
# Negative log-likelihood (step: 6800000): 56767.934017
# Negative log-likelihood (step: 6810000): 55205.016336
# Negative log-likelihood (step: 6820000): 55176.825124
# Negative log-likelihood (step: 6830000): 57250.845773
# Negative log-likelihood (step: 6840000): 55998.114713
# Negative log-likelihood (step: 6850000): 55951.851960
# Negative log-likelihood (step: 6860000): 57062.940147
# Negative log-likelihood (step: 6870000): 57535.459051
# Negative log-likelihood (step: 6880000): 54684.952833
# Negative log-likelihood (step: 6890000): 57086.879496
# Negative log-likelihood (step: 6900000): 54283.589560
# Negative log-likelihood (step: 6910000): 56603.324783
# Negative log-likelihood (step: 6920000): 56187.963118
# Negative log-likelihood (step: 6930000): 54980.169025
# Negative log-likelihood (step: 6940000): 56142.109299
# Negative log-likelihood (step: 6950000): 54927.049211
# Negative log-likelihood (step: 6960000): 55353.411087
# Negative log-likelihood (step: 6970000): 54845.170967
# Negative log-likelihood (step: 6980000): 55557.220028
# Negative log-likelihood (step: 6990000): 55015.264341
# Negative log-likelihood (step: 7000000): 54749.680687
# Negative log-likelihood (step: 7010000): 55144.134498
# Negative log-likelihood (step: 7020000): 55772.476385
# Negative log-likelihood (step: 7030000): 55756.619161
# Negative log-likelihood (step: 7040000): 56281.673759
# Negative log-likelihood (step: 7050000): 56744.145211
# Negative log-likelihood (step: 7060000): 54041.075517
# Negative log-likelihood (step: 7070000): 55414.956855
# Negative log-likelihood (step: 7080000): 55550.796885
# Negative log-likelihood (step: 7090000): 55296.615678
# Negative log-likelihood (step: 7100000): 54422.056567
# Negative log-likelihood (step: 7110000): 55022.639684
# Negative log-likelihood (step: 7120000): 56887.680360
# Negative log-likelihood (step: 7130000): 55854.987541
# Negative log-likelihood (step: 7140000): 54392.953362
# Negative log-likelihood (step: 7150000): 56326.249790
# Negative log-likelihood (step: 7160000): 54280.603473
# Negative log-likelihood (step: 7170000): 55190.761309
# Negative log-likelihood (step: 7180000): 57188.810156
# Negative log-likelihood (step: 7190000): 54053.907125
# Negative log-likelihood (step: 7200000): 56814.209398
# Negative log-likelihood (step: 7210000): 52043.258312
# Negative log-likelihood (step: 7220000): 58031.663836
# Negative log-likelihood (step: 7230000): 56927.505328
# Negative log-likelihood (step: 7240000): 51523.610203
# Negative log-likelihood (step: 7250000): 55389.330800
# Negative log-likelihood (step: 7260000): 54323.244264
# Negative log-likelihood (step: 7270000): 55524.957656
# Negative log-likelihood (step: 7280000): 54558.617280
# Negative log-likelihood (step: 7290000): 56773.736547
# Negative log-likelihood (step: 7300000): 55863.212261
# Negative log-likelihood (step: 7310000): 55276.505158
# Negative log-likelihood (step: 7320000): 55080.907705
# Negative log-likelihood (step: 7330000): 56227.432738
# Negative log-likelihood (step: 7340000): 56567.902347
# Negative log-likelihood (step: 7350000): 56643.093880
# Negative log-likelihood (step: 7360000): 55471.577707
# Negative log-likelihood (step: 7370000): 54220.051719
# Negative log-likelihood (step: 7380000): 51377.414250
# Negative log-likelihood (step: 7390000): 55310.751734
# Negative log-likelihood (step: 7400000): 56417.462879
# Negative log-likelihood (step: 7410000): 57275.333403
# Negative log-likelihood (step: 7420000): 55124.716063
# Negative log-likelihood (step: 7430000): 53843.414311
# Negative log-likelihood (step: 7440000): 54479.292287
# Negative log-likelihood (step: 7450000): 54026.378401
# Negative log-likelihood (step: 7460000): 54091.131380
# Negative log-likelihood (step: 7470000): 56531.083593
# Negative log-likelihood (step: 7480000): 47931.076043
# Negative log-likelihood (step: 7490000): 55893.030277
# Negative log-likelihood (step: 7500000): 57129.461017
# Negative log-likelihood (step: 7510000): 53862.810192
# Negative log-likelihood (step: 7520000): 55576.460751
# Negative log-likelihood (step: 7530000): 56277.427193
# Negative log-likelihood (step: 7540000): 55916.204831
# Negative log-likelihood (step: 7550000): 56130.242330
# Negative log-likelihood (step: 7560000): 55202.160962
# Negative log-likelihood (step: 7570000): 54917.314074
# Negative log-likelihood (step: 7580000): 57043.935198
# Negative log-likelihood (step: 7590000): 56207.789378
# Negative log-likelihood (step: 7600000): 57257.696004
# Negative log-likelihood (step: 7610000): 56211.931806
# Negative log-likelihood (step: 7620000): 52023.169518
# Negative log-likelihood (step: 7630000): 55142.501871
# Negative log-likelihood (step: 7640000): 55991.968826
# Negative log-likelihood (step: 7650000): 55206.753698
# Negative log-likelihood (step: 7660000): 57128.874064
# Negative log-likelihood (step: 7670000): 53588.036954
# Negative log-likelihood (step: 7680000): 54615.362550
# Negative log-likelihood (step: 7690000): 54615.668908
# Negative log-likelihood (step: 7700000): 54102.528918
# Negative log-likelihood (step: 7710000): 56927.827406
# Negative log-likelihood (step: 7720000): 51165.441024
# Negative log-likelihood (step: 7730000): 55318.650773
# Negative log-likelihood (step: 7740000): 54573.818811
# Negative log-likelihood (step: 7750000): 53615.253874
# Negative log-likelihood (step: 7760000): 56388.978362
# Negative log-likelihood (step: 7770000): 55802.084860
# Negative log-likelihood (step: 7780000): 55328.638133
# Negative log-likelihood (step: 7790000): 54859.552778
# Negative log-likelihood (step: 7800000): 52437.713034
# Negative log-likelihood (step: 7810000): 55806.665800
# Negative log-likelihood (step: 7820000): 57188.629621
# Negative log-likelihood (step: 7830000): 55896.842360
# Negative log-likelihood (step: 7840000): 56139.579699
# Negative log-likelihood (step: 7850000): 53961.673361
# Negative log-likelihood (step: 7860000): 57038.920352
# Negative log-likelihood (step: 7870000): 56212.306578
# Negative log-likelihood (step: 7880000): 54512.821361
# Negative log-likelihood (step: 7890000): 54529.083532
# Negative log-likelihood (step: 7900000): 57391.808769
# Negative log-likelihood (step: 7910000): 56327.901146
# Negative log-likelihood (step: 7920000): 56520.771436
# Negative log-likelihood (step: 7930000): 57058.509810
# Negative log-likelihood (step: 7940000): 57416.706300
# Negative log-likelihood (step: 7950000): 55458.158423
# Negative log-likelihood (step: 7960000): 55699.971525
# Negative log-likelihood (step: 7970000): 56580.860349
# Negative log-likelihood (step: 7980000): 56402.697918
# Negative log-likelihood (step: 7990000): 55670.095041
# Negative log-likelihood (step: 8000000): 56255.097682
# Negative log-likelihood (step: 8010000): 55672.050455
# Negative log-likelihood (step: 8020000): 56167.453654
# Negative log-likelihood (step: 8030000): 55500.277864
# Negative log-likelihood (step: 8040000): 55092.971866
# Negative log-likelihood (step: 8050000): 53946.384469
# Negative log-likelihood (step: 8060000): 55519.962273
# Negative log-likelihood (step: 8070000): 54608.612039
# Negative log-likelihood (step: 8080000): 55079.153473
# Negative log-likelihood (step: 8090000): 56461.786120
# Negative log-likelihood (step: 8100000): 56842.550811
# Negative log-likelihood (step: 8110000): 54793.009098
# Negative log-likelihood (step: 8120000): 54969.298271
# Negative log-likelihood (step: 8130000): 57501.287953
# Negative log-likelihood (step: 8140000): 56773.955986
# Negative log-likelihood (step: 8150000): 57692.968406
# Negative log-likelihood (step: 8160000): 55810.148029
# Negative log-likelihood (step: 8170000): 56452.017155
# Negative log-likelihood (step: 8180000): 53375.103627
# Negative log-likelihood (step: 8190000): 52516.384400
# Negative log-likelihood (step: 8200000): 53209.338831
# Negative log-likelihood (step: 8210000): 54499.167128
# Negative log-likelihood (step: 8220000): 56856.201421
# Negative log-likelihood (step: 8230000): 58383.842792
# Negative log-likelihood (step: 8240000): 55062.377816
# Negative log-likelihood (step: 8250000): 55362.314149
# Negative log-likelihood (step: 8260000): 54283.386493
# Negative log-likelihood (step: 8270000): 56134.801824
# Negative log-likelihood (step: 8280000): 56077.919043
# Negative log-likelihood (step: 8290000): 55686.175883
# Negative log-likelihood (step: 8300000): 55131.741908
# Negative log-likelihood (step: 8310000): 55819.726031
# Negative log-likelihood (step: 8320000): 55315.335129
# Negative log-likelihood (step: 8330000): 55272.147908
# Negative log-likelihood (step: 8340000): 56432.084649
# Negative log-likelihood (step: 8350000): 56761.714015
# Negative log-likelihood (step: 8360000): 56241.604969
# Negative log-likelihood (step: 8370000): 56041.224824
# Negative log-likelihood (step: 8380000): 54429.934774
# Negative log-likelihood (step: 8390000): 55896.489937
# Negative log-likelihood (step: 8400000): 57022.669848
# Negative log-likelihood (step: 8410000): 50155.537115
# Negative log-likelihood (step: 8420000): 55758.758543
# Negative log-likelihood (step: 8430000): 54950.434715
# Negative log-likelihood (step: 8440000): 53483.630530
# Negative log-likelihood (step: 8450000): 50827.985709
# Negative log-likelihood (step: 8460000): 50392.028056
# Negative log-likelihood (step: 8470000): 56086.832598
# Negative log-likelihood (step: 8480000): 55798.502693
# Negative log-likelihood (step: 8490000): 53380.550006
# Negative log-likelihood (step: 8500000): 54914.661013
# Negative log-likelihood (step: 8510000): 56244.358347
# Negative log-likelihood (step: 8520000): 57620.107956
# Negative log-likelihood (step: 8530000): 56871.730976
# Negative log-likelihood (step: 8540000): 56727.983437
# Negative log-likelihood (step: 8550000): 56716.614504
# Negative log-likelihood (step: 8560000): 53991.892402
# Negative log-likelihood (step: 8570000): 55454.905084
# Negative log-likelihood (step: 8580000): 55701.297355
# Negative log-likelihood (step: 8590000): 55562.323707
# Negative log-likelihood (step: 8600000): 55809.309647
# Negative log-likelihood (step: 8610000): 56535.620591
# Negative log-likelihood (step: 8620000): 56610.097828
# Negative log-likelihood (step: 8630000): 56211.921750
# Negative log-likelihood (step: 8640000): 56545.014975
# Negative log-likelihood (step: 8650000): 56551.317408
# Negative log-likelihood (step: 8660000): 56083.685607
# Negative log-likelihood (step: 8670000): 55515.927541
# Negative log-likelihood (step: 8680000): 57257.988991
# Negative log-likelihood (step: 8690000): 57400.380905
# Negative log-likelihood (step: 8700000): 57745.526969
# Negative log-likelihood (step: 8710000): 57018.706715
# Negative log-likelihood (step: 8720000): 57048.992162
# Negative log-likelihood (step: 8730000): 54082.637420
# Negative log-likelihood (step: 8740000): 52544.087726
# ...
# Negative log-likelihood (step: 33410000): 53766.182250
# Negative log-likelihood (step: 33420000): 52493.321713
# Negative log-likelihood (step: 33430000): 55686.849072
# Negative log-likelihood (step: 33440000): 53990.618869
# Negative log-likelihood (step: 33450000): 55532.782291
# Negative log-likelihood (step: 33460000): 56203.890718
# Negative log-likelihood (step: 33470000): 55660.441752
# Negative log-likelihood (step: 33480000): 55844.158101
# Negative log-likelihood (step: 33490000): 53393.855386
# Negative log-likelihood (step: 33500000): 55123.911187
# Negative log-likelihood (step: 33510000): 54159.561330
# Negative log-likelihood (step: 33520000): 54588.603265
# Negative log-likelihood (step: 33530000): 55748.195837
# Negative log-likelihood (step: 33540000): 55161.592266
# Negative log-likelihood (step: 33550000): 55612.952761
# Negative log-likelihood (step: 33560000): 56681.806190
# Negative log-likelihood (step: 33570000): 54794.680575
# Negative log-likelihood (step: 33580000): 54828.198301
# Negative log-likelihood (step: 33590000): 52581.686741
# Negative log-likelihood (step: 33600000): 55527.219610
# Negative log-likelihood (step: 33610000): 53867.714902
# Negative log-likelihood (step: 33620000): 53562.481228
# Negative log-likelihood (step: 33630000): 55755.659713
# Negative log-likelihood (step: 33640000): 56097.195020
# Negative log-likelihood (step: 33650000): 55605.130064
# Negative log-likelihood (step: 33660000): 54430.832002
# Negative log-likelihood (step: 33670000): 55087.137231
# Negative log-likelihood (step: 33680000): 57187.402275
# Negative log-likelihood (step: 33690000): 55197.874548
# Negative log-likelihood (step: 33700000): 51265.446849
# Negative log-likelihood (step: 33710000): 51270.683082
# Negative log-likelihood (step: 33720000): 54908.286659
# Negative log-likelihood (step: 33730000): 53931.969633
# Negative log-likelihood (step: 33740000): 55655.984796
# Negative log-likelihood (step: 33750000): 56296.892775
# Negative log-likelihood (step: 33760000): 51840.100269
# Negative log-likelihood (step: 33770000): 52573.667200
# Negative log-likelihood (step: 33780000): 53480.624514
# Negative log-likelihood (step: 33790000): 53610.796079
# Negative log-likelihood (step: 33800000): 54534.712134
# Negative log-likelihood (step: 33810000): 54087.163871
# Negative log-likelihood (step: 33820000): 54073.755712
# Negative log-likelihood (step: 33830000): 55337.968040
# Negative log-likelihood (step: 33840000): 54004.811542
# Negative log-likelihood (step: 33850000): 55127.577347
# Negative log-likelihood (step: 33860000): 56585.752796
# Negative log-likelihood (step: 33870000): 54920.599174
# Negative log-likelihood (step: 33880000): 55658.691485
# Negative log-likelihood (step: 33890000): 53617.287618
# Negative log-likelihood (step: 33900000): 55732.051838
# Negative log-likelihood (step: 33910000): 50724.899722
# Negative log-likelihood (step: 33920000): 55741.025686
# Negative log-likelihood (step: 33930000): 54099.200586
# Negative log-likelihood (step: 33940000): 51588.907808
# Negative log-likelihood (step: 33950000): 53861.104338
# Negative log-likelihood (step: 33960000): 54181.224506
# Negative log-likelihood (step: 33970000): 53261.677391
# Negative log-likelihood (step: 33980000): 56225.698197
# Negative log-likelihood (step: 33990000): 52330.542462
# Negative log-likelihood (step: 34000000): 55793.249485
# Negative log-likelihood (step: 34010000): 54914.833558
# Negative log-likelihood (step: 34020000): 55726.385629
# Negative log-likelihood (step: 34030000): 55109.645167
# Negative log-likelihood (step: 34040000): 54477.925149
# Negative log-likelihood (step: 34050000): 51873.905023
# Negative log-likelihood (step: 34060000): 53054.993425
# Negative log-likelihood (step: 34070000): 54848.240878
# Negative log-likelihood (step: 34080000): 53480.862939
# Negative log-likelihood (step: 34090000): 55509.180196
# Negative log-likelihood (step: 34100000): 51489.262200
# Negative log-likelihood (step: 34110000): 54161.968757
# Negative log-likelihood (step: 34120000): 54302.200738
# Negative log-likelihood (step: 34130000): 56977.693115
# Negative log-likelihood (step: 34140000): 56464.194014
# Negative log-likelihood (step: 34150000): 55076.052576
# Negative log-likelihood (step: 34160000): 55653.819978
# Negative log-likelihood (step: 34170000): 54842.860860
# Negative log-likelihood (step: 34180000): 55611.094605
# Negative log-likelihood (step: 34190000): 55399.225091
# Negative log-likelihood (step: 34200000): 54650.002199
# Negative log-likelihood (step: 34210000): 53919.659937
# Negative log-likelihood (step: 34220000): 55448.415205
# Negative log-likelihood (step: 34230000): 55656.046566
# Negative log-likelihood (step: 34240000): 52319.602679
# Negative log-likelihood (step: 34250000): 51087.838713
# Negative log-likelihood (step: 34260000): 54822.066785
# Negative log-likelihood (step: 34270000): 53897.202527
# Negative log-likelihood (step: 34280000): 50892.721392
# Negative log-likelihood (step: 34290000): 55770.203538
# Negative log-likelihood (step: 34300000): 55329.053411
# Negative log-likelihood (step: 34310000): 50199.413103
# Negative log-likelihood (step: 34320000): 54988.130106
# Negative log-likelihood (step: 34330000): 55942.395216
# Negative log-likelihood (step: 34340000): 56438.567632
# Negative log-likelihood (step: 34350000): 55751.035175
# Negative log-likelihood (step: 34360000): 56956.671977
# Negative log-likelihood (step: 34370000): 55931.716919
# Negative log-likelihood (step: 34380000): 55231.355120
# Negative log-likelihood (step: 34390000): 54057.889297
# Negative log-likelihood (step: 34400000): 54684.204118
# Negative log-likelihood (step: 34410000): 55951.902551
# Negative log-likelihood (step: 34420000): 54004.709439
# Negative log-likelihood (step: 34430000): 53521.492543
# Negative log-likelihood (step: 34440000): 52093.995135
# Negative log-likelihood (step: 34450000): 54864.055055
# Negative log-likelihood (step: 34460000): 55142.243472
# Negative log-likelihood (step: 34470000): 55951.920797
# Negative log-likelihood (step: 34480000): 54621.978727
# Negative log-likelihood (step: 34490000): 52628.616212
# Negative log-likelihood (step: 34500000): 55874.010343
# Negative log-likelihood (step: 34510000): 55652.828698
# Negative log-likelihood (step: 34520000): 55024.351181
# Negative log-likelihood (step: 34530000): 56456.870677
# Negative log-likelihood (step: 34540000): 55869.048188
# Negative log-likelihood (step: 34550000): 55348.280072
# Negative log-likelihood (step: 34560000): 54116.637384
# Negative log-likelihood (step: 34570000): 55130.719691
# Negative log-likelihood (step: 34580000): 54007.508676
# Negative log-likelihood (step: 34590000): 52041.636351
# Negative log-likelihood (step: 34600000): 54434.306898
# Negative log-likelihood (step: 34610000): 56558.322304
# Negative log-likelihood (step: 34620000): 55374.455607
# Negative log-likelihood (step: 34630000): 56260.887692
# Negative log-likelihood (step: 34640000): 55548.204449
# Negative log-likelihood (step: 34650000): 53757.832313
# Negative log-likelihood (step: 34660000): 52700.483053
# Negative log-likelihood (step: 34670000): 54569.676430
# Negative log-likelihood (step: 34680000): 55313.047194
# Negative log-likelihood (step: 34690000): 54841.042226
# Negative log-likelihood (step: 34700000): 54285.757749
# Negative log-likelihood (step: 34710000): 55123.122338
# Negative log-likelihood (step: 34720000): 55121.537914
# Negative log-likelihood (step: 34730000): 54924.202201
# Negative log-likelihood (step: 34740000): 55447.798018
# Negative log-likelihood (step: 34750000): 53750.767211
# Negative log-likelihood (step: 34760000): 51847.841309
# Negative log-likelihood (step: 34770000): 55339.111804
# Negative log-likelihood (step: 34780000): 55102.899369
# Negative log-likelihood (step: 34790000): 53388.789354
# Negative log-likelihood (step: 34800000): 55692.297944
# Negative log-likelihood (step: 34810000): 53411.250404
# Negative log-likelihood (step: 34820000): 55463.079374
# Negative log-likelihood (step: 34830000): 46441.280009
# Negative log-likelihood (step: 34840000): 54666.309302
# Negative log-likelihood (step: 34850000): 55897.120239
# Negative log-likelihood (step: 34860000): 56188.090040
# Negative log-likelihood (step: 34870000): 56738.605386
# Negative log-likelihood (step: 34880000): 53998.335761
# Negative log-likelihood (step: 34890000): 55771.396886
# Negative log-likelihood (step: 34900000): 56674.770982
# Negative log-likelihood (step: 34910000): 54924.440170
# Negative log-likelihood (step: 34920000): 55349.954209
# Negative log-likelihood (step: 34930000): 55203.984350
# Negative log-likelihood (step: 34940000): 55517.795352
# Negative log-likelihood (step: 34950000): 52493.267928
# Negative log-likelihood (step: 34960000): 53739.471626
# Negative log-likelihood (step: 34970000): 55583.443883
# Negative log-likelihood (step: 34980000): 52982.520405
# Negative log-likelihood (step: 34990000): 54161.475070
# Negative log-likelihood (step: 35000000): 56726.482977
# Negative log-likelihood (step: 35010000): 54252.920426
# Negative log-likelihood (step: 35020000): 55551.531456
# Negative log-likelihood (step: 35030000): 56584.800888
# Negative log-likelihood (step: 35040000): 53003.963937
# Negative log-likelihood (step: 35050000): 53742.464628
# Negative log-likelihood (step: 35060000): 52560.902277
# Negative log-likelihood (step: 35070000): 55376.722500
# Negative log-likelihood (step: 35080000): 52676.222262
# Negative log-likelihood (step: 35090000): 54842.568957
# Negative log-likelihood (step: 35100000): 55053.422089
# Negative log-likelihood (step: 35110000): 53918.315202
# Negative log-likelihood (step: 35120000): 55484.333040
# Negative log-likelihood (step: 35130000): 55214.222119
# Negative log-likelihood (step: 35140000): 52767.185476
# Negative log-likelihood (step: 35150000): 56610.532368
# Negative log-likelihood (step: 35160000): 55901.548237
# Negative log-likelihood (step: 35170000): 56271.687200
# Negative log-likelihood (step: 35180000): 54415.020537
# Negative log-likelihood (step: 35190000): 55768.320702
# Negative log-likelihood (step: 35200000): 54132.344384
# Negative log-likelihood (step: 35210000): 54496.477970
# Negative log-likelihood (step: 35220000): 54516.661546
# Negative log-likelihood (step: 35230000): 56066.304054
# Negative log-likelihood (step: 35240000): 55555.326409
# Negative log-likelihood (step: 35250000): 54052.178668
# Negative log-likelihood (step: 35260000): 54841.239968
# Negative log-likelihood (step: 35270000): 53422.890088
# Negative log-likelihood (step: 35280000): 56122.895982
# Negative log-likelihood (step: 35290000): 56184.746339
# Negative log-likelihood (step: 35300000): 56578.824618
# Negative log-likelihood (step: 35310000): 56021.600501
# Negative log-likelihood (step: 35320000): 55218.948023
# Negative log-likelihood (step: 35330000): 54235.433854
# Negative log-likelihood (step: 35340000): 54931.001612
# Negative log-likelihood (step: 35350000): 56206.962285
# Negative log-likelihood (step: 35360000): 55440.503007
# Negative log-likelihood (step: 35370000): 54042.393909
# Negative log-likelihood (step: 35380000): 55222.057093
# Negative log-likelihood (step: 35390000): 56240.654716
# Negative log-likelihood (step: 35400000): 52988.415796
# Negative log-likelihood (step: 35410000): 55084.139367
# Negative log-likelihood (step: 35420000): 55873.436121
# Negative log-likelihood (step: 35430000): 52321.726293
# Negative log-likelihood (step: 35440000): 54133.375900
# Negative log-likelihood (step: 35450000): 54087.486092
# Negative log-likelihood (step: 35460000): 52982.873337
# Negative log-likelihood (step: 35470000): 54762.204087
# Negative log-likelihood (step: 35480000): 54282.405887
# Negative log-likelihood (step: 35490000): 53485.145215
# Negative log-likelihood (step: 35500000): 54084.365772
# Negative log-likelihood (step: 35510000): 56202.776008
# Negative log-likelihood (step: 35520000): 53529.719781
# Negative log-likelihood (step: 35530000): 56374.695663
# Negative log-likelihood (step: 35540000): 54994.376038
# Negative log-likelihood (step: 35550000): 54558.154865
# Negative log-likelihood (step: 35560000): 54848.789706
# Negative log-likelihood (step: 35570000): 54794.500124
# Negative log-likelihood (step: 35580000): 54433.566267
# Negative log-likelihood (step: 35590000): 54373.632496
# Negative log-likelihood (step: 35600000): 54786.031394
# Negative log-likelihood (step: 35610000): 54049.577446
# Negative log-likelihood (step: 35620000): 50886.503946
# Negative log-likelihood (step: 35630000): 52851.057840
# Negative log-likelihood (step: 35640000): 54755.187913
# Negative log-likelihood (step: 35650000): 54154.384153
# Negative log-likelihood (step: 35660000): 54256.180277
# Negative log-likelihood (step: 35670000): 55555.634274
# Negative log-likelihood (step: 35680000): 54793.760359
# Negative log-likelihood (step: 35690000): 53328.334912
# Negative log-likelihood (step: 35700000): 53597.412225
# Negative log-likelihood (step: 35710000): 56549.869095
# Negative log-likelihood (step: 35720000): 54718.852647
# Negative log-likelihood (step: 35730000): 55274.731294
# Negative log-likelihood (step: 35740000): 56105.757363
# Negative log-likelihood (step: 35750000): 55732.580983
# Negative log-likelihood (step: 35760000): 56009.536358
# Negative log-likelihood (step: 35770000): 56268.866836
# Negative log-likelihood (step: 35780000): 54747.668599
# Negative log-likelihood (step: 35790000): 55564.661496
# Negative log-likelihood (step: 35800000): 55443.237856
# Negative log-likelihood (step: 35810000): 55895.539449
# Negative log-likelihood (step: 35820000): 55526.872809
# Negative log-likelihood (step: 35830000): 53014.563731
# Negative log-likelihood (step: 35840000): 53904.347371
# Negative log-likelihood (step: 35850000): 55182.659600
# Negative log-likelihood (step: 35860000): 55333.094353
# Negative log-likelihood (step: 35870000): 56234.149233
# Negative log-likelihood (step: 35880000): 55255.924126
# Negative log-likelihood (step: 35890000): 54936.234489
# Negative log-likelihood (step: 35900000): 55645.569638
# Negative log-likelihood (step: 35910000): 54909.688070
# Negative log-likelihood (step: 35920000): 56178.779912
# Negative log-likelihood (step: 35930000): 55006.665700
# Negative log-likelihood (step: 35940000): 53437.403892
# Negative log-likelihood (step: 35950000): 55973.117068
# Negative log-likelihood (step: 35960000): 53538.636812
# Negative log-likelihood (step: 35970000): 55622.331997
# Negative log-likelihood (step: 35980000): 56695.290705
# Negative log-likelihood (step: 35990000): 52865.463753
# Negative log-likelihood (step: 36000000): 55086.962564
# Negative log-likelihood (step: 36010000): 55616.069511
# Negative log-likelihood (step: 36020000): 52525.469217
# Negative log-likelihood (step: 36030000): 56718.748980
# Negative log-likelihood (step: 36040000): 54085.723112
# Negative log-likelihood (step: 36050000): 55610.351981
# Negative log-likelihood (step: 36060000): 56722.001498
# Negative log-likelihood (step: 36070000): 56504.446377
# Negative log-likelihood (step: 36080000): 54920.570837
# Negative log-likelihood (step: 36090000): 55138.784291
# Negative log-likelihood (step: 36100000): 54028.366696
# Negative log-likelihood (step: 36110000): 53665.467163
# Negative log-likelihood (step: 36120000): 53610.755167
# Negative log-likelihood (step: 36130000): 55498.341423
# Negative log-likelihood (step: 36140000): 56697.096905
# Negative log-likelihood (step: 36150000): 53217.801763
# Negative log-likelihood (step: 36160000): 51899.891152
# Negative log-likelihood (step: 36170000): 51674.672019
# Negative log-likelihood (step: 36180000): 56338.974057
# Negative log-likelihood (step: 36190000): 54372.407047
# Negative log-likelihood (step: 36200000): 56268.052104
# Negative log-likelihood (step: 36210000): 55614.287689
# Negative log-likelihood (step: 36220000): 53985.384621
# Negative log-likelihood (step: 36230000): 56214.970543
# Negative log-likelihood (step: 36240000): 53752.007765
# Negative log-likelihood (step: 36250000): 54815.293970

# %%
instance.save('trained_vector_synonym.txt')
